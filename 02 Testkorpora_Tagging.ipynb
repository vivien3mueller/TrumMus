# %% [markdown]
# # 02 Testkorpora_Tagging

# %% [markdown]
# ! Für folgendes Notebook wurden verschiedene Kernel benutzt, da einige Modelle fürs POS-Tagging besondere Anforderungen an die Version der Pakete hatten, welche mit anderen Paketversionen für andere Modelle nicht kompatibel sind.

# %% [markdown]
# ## Tagger für POS
# In diesem Jupyter Notebook wird ein Testkorpus testkorpus_divers_50.csv erstellt, welches verschiedene Schwierigkeiten wie Rechtschreibfehler, Hashes, @ und Emojis enthält. Danach wird die Datei anhand mehrerer verschiedener Modelle getaggt, sodass verglichen werden kann, welches Modell am besten abschneidet. Die Entscheidung wird mit meinem persönlichen Eindruck begründet und nicht quantifiziert.
# Im Folgenden werden immer die gleichen 50 Zeilen der Testkorpora gezeigt, um einen ersten Eindruck der Performance zu erhalten. Für einen zuverlässigen und quaitativ höheren Eindruck öffnete ich die Dateien allerdings alle einzeln und verglich Zeile für Zeile miteinander.

# %% [markdown]
# Verschiedene Tagsets:
# - Penn Treebank Tags: https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html
# - Universal Dependencies:
# https://universaldependencies.org/u/pos/
# https://huggingface.co/flair/upos-english

# %% [markdown]
# ### Welcher Tagger eignet sich am Besten:
# - Spacy
# - Stanza
# - Flair
# - Bert
# - Tweebank
# - andere Varianten

# %% [markdown]
# #### Testkorpus, mit dem verschiedene Tagger getestet werden:

# %%
# Installation: conda install -c conda-forge pyspellchecker

# %%
# Ziel: ein möglichst diverses Korpus erstellen, das alle relevanten Fälle prüft
import pandas as pd
import re
from spellchecker import SpellChecker
from IPython.display import display

spell = SpellChecker(language="en")
df = pd.read_csv("tta_final_clean.csv")

# Funktionen für verschiedene Post-Typen
def has_mention(x): return "@" in str(x)
def has_hashtag(x): return "#" in str(x)
def has_url(x): return re.search(r"http[s]?://", str(x)) is not None
def has_emoji(x): return re.search(r"[\U00010000-\U0010ffff]", str(x)) is not None
def is_long(x): return len(str(x)) > 200
def has_typo(x): return re.compile(
    r"\b("
    r"teh|recieve|definately|seperat(?:e|ely)|occured|untill|wich|"
    r"neccessary|adress|tomm?orow|becuase|wierd|yeee?s"
    r")\b",
    flags=re.IGNORECASE
)
def has_typo_spellchecker(text):
    words = str(text).split()
    misspelled = spell.unknown(words)   # Wörter, die nicht im Wörterbuch sind
    return len(misspelled) > 0

samples = []
# je 5 Beispiele (wenn vorhanden)
samples.append(df[df['text'].apply(is_long)].sample(n=5, random_state=1))
samples.append(df[df['text'].apply(has_mention)].sample(n=5, random_state=2))
samples.append(df[df['text'].apply(has_hashtag)].sample(n=5, random_state=3))
samples.append(df[df['text'].apply(has_url)].sample(n=5, random_state=4))
samples.append(df[df['text'].apply(has_emoji)].sample(n=5, random_state=5))
#samples.append(df[df['text'].apply(has_typo)].sample(n=5, random_state=6))
samples.append(df[df["text"].apply(has_typo_spellchecker)].sample(n=5, random_state=6))
#df["text"].apply(has_typo_spellchecker)

# Rest zufällig auffüllen bis 50
already = pd.concat(samples)
remaining = df.drop(already.index)
rest = remaining.sample(n=50-len(already), random_state=42)

# finales Testkorpus
test_divers = pd.concat([already, rest]).sample(frac=1, random_state=99)
test_divers.to_csv("test_full.csv", index=False)
test_divers = test_divers[['date', 'id', 'text']]
display(test_divers.head(50))
test_divers.to_csv("testkorpus_divers_50.csv", index=False)
# Anmerkung: statt print verwende ich aufgrund der schöneren Ansicht display
# Out:
#              date                   id  \
# 41873  2010-11-04           3498743628
# 48694  2013-08-15   367977996541788160
# 50189  2013-06-12   344775405057753088
# 14002  2011-09-04   110498268480198144
# 35985  2020-05-11  1259672385286012928
# 11663  2011-09-07   111274504071323312
# 22194  2011-09-01   109360482610823936
# 2495   2025-03-19                 2755
# 84855  2019-01-23  1087867453684834304
# 63673  2015-07-01   616265476616900608
# 73306  2017-07-21   888429879603191808
# 25584  2011-08-31   108982117859170992
# 75452  2018-10-03  1047477260624773120
# 74381  2017-01-12   819541997325316096
# 64455  2015-05-21   601265719007944704
# 1204   2025-06-17                 1308
# 480    2025-07-27                  537
# 16522  2011-09-07   111495112104730624
# 58345  2014-05-23   469850924102737920
# 62504  2015-09-02   639018768665063424
# 34847  2020-04-06  1247268841845141504
# 38961  2020-03-24  1242432301885198336
# 16744  2011-09-07   111454972255115328
# 33783  2019-12-25  1209838086730981376
# 2610   2025-03-12                 2877
# 3211   2025-01-31                 3717
# 12733  2011-09-06   111092587326199136
# 31395  2018-11-02  1058482506037641216
# 72689  2017-09-27   913034591879024640
# 56697  2014-09-01   506380656998641664
# 49389  2013-07-17   357591410251284480
# 31099  2020-11-07  1324928487807995904
# 26930  2011-09-11   112707729209876672
# 64605  2015-05-15   599019686286774272
# 82034  2019-07-24  1153992334054440960
# 33698  2020-05-07  1258465767751856128
# 73710  2017-05-20   865957909565366272
# 38651  2020-08-20  1296579488998928384
# 32258  2020-06-11  1271082251791499264
# 18604  2011-09-12   113125743674703328
# 79037  2019-11-13  1194414141550796800
# 49923  2013-06-28   350632506485243904
# 13576  2011-09-05   110579568469291920
# 13843  2011-09-05   110519725006339152
# 34004  2020-06-14  1272155593143353344
# 58615  2014-05-02   462220477185150976
# 57196  2014-07-22   491668720444792832
# 31889  2020-05-02  1256625602528006144
# 55874  2014-10-17   523144417532997632
# 2772   2025-03-01                 3157
#
#                                                     text
# 41873  Reminder: The Miss Universe competition will b...
# 48694                                  @Timc1021 Thanks!
# 50189  ""@_KatherineWebb: Looking forward to #MissUSA...
# 14002  Addressing  the Rise of Chronic Childhood Illn...
# 35985  RT @darhar981: Attorney General Barr’s Office ...
# 11663           RT  @MagaGlam🇺🇸♥️ Bring Back  Trump  💙🇺🇸
# 22194                                                NaN
# 2495   The CBP Home App is now available across all m...
# 84855  Congratulations to Mariano Rivera on unanimous...
# 63673  My recent statement re: @macys -- We must have...
# 73306  ICYMI- This week we hosted a #MadeInAmerica ev...
# 25584  https://www.mediaite.com/tv/trump-team-scored-...
# 75452  Thank you Governor Phil Bryant - it was my gre...
# 74381  Thank you to Linda Bean of L.L.Bean for your g...
# 64455  ""@HarmonBrew: @FoxNews @megynkelly  DonaldTru...
# 1204   We now have complete and total control of the ...
# 480    https://www.thegatewaypundit.com/2025/07/her-b...
# 16522  https://www.foxnews.com/politics/hunter-biden-...
# 58345  Via @BreitbartNews by @TheTonyLee: ""@Citizens...
# 62504  ""@LBabcock2:  @oreillyfactor @FoxNews I have ...
# 34847  Congratulations to State Representative Karen ...
# 38961  Congress must approve the deal, without all of...
# 16744  https://justthenews.com/politics-policy/all-th...
# 33783  RT @FLOTUS: Wishing you all a very #MerryChris...
# 2610   The United States of America is going to take ...
# 3211                                                 NaN
# 12733  RT  @mrddmiaIf Trump didn't  incite the Januar...
# 31395    JOBS, JOBS, JOBS! #MAGA https://t.co/ZqPjsPUX0t
# 72689  Facebook was always anti-Trump.The Networks we...
# 56697  ""@NPHerron: @realDonaldTrump For president #2...
# 49389  The Zimmerman trial is over.  It is time to mo...
# 31099  RT @dbongino: The Polls Were More Wrong in 202...
# 26930  RT  @IStandWithTrump47November 5th can’t  come...
# 64605  ""@JDrago28: It was such an honor to meet @rea...
# 82034  Why didn’t Robert Mueller &amp, his band of 18...
# 33698  Today, @FLOTUS celebrates the two year anniver...
# 73710  Thank you to the BRAVE servicemen &amp, women ...
# 38651  THANK YOU PENNSYLVANIA! #MAGA https://t.co/5Bf...
# 32258  THOSE THAT DENY THEIR HISTORY ARE DOOMED TO RE...
# 18604  https://www.washingtonexaminer.com/news/campai...
# 79037  RT @IvankaTrump: It is an honor to serve our g...
# 49923  Situated in the heart of downtown Toronto, the...
# 13576  RT  @realDonaldTrumpUsing Impoundment to  Slas...
# 13843  RT  @gatewaypunditANOTHER  BOGUS ATTACK: DC Co...
# 34004          Thank you Philip! https://t.co/jGspqbtSgL
# 58615  With @VanityFair circulation and advertising r...
# 57196  Thanks @LilJon for coming to my defense in Rol...
# 31889  RT @ScottAdamsSays: Poll for Democrats only. A...
# 55874  I love seeing that Graydon Carter and @VanityF...
# 2772   The month of February, my first full month in ...

# %%
test_divers.shape
# Out:
# (50, 3)

# %%
test_divers.to_json("testkorpus_divers_50.json", orient="records", force_ascii=False, indent=2)

# %% [markdown]
# # SpaCy
# https://huggingface.co/spacy/en_core_web_sm

# %%
# !pip install spacy

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("Donald Trump posted a new tweet. #realdonaldtrump @realdonaldtrump! @ben4appel 🤣 :) https://t.co/bsB6rVV7Yn")
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_)
# besser wäre, wenn die Hashes nicht zerlegt werden.
# und Emojis nicht als Eigennamen angesehen werden
# Out:
# Donald Donald PROPN NNP
# Trump Trump PROPN NNP
# posted post VERB VBD
# a a DET DT
# new new ADJ JJ
# tweet tweet NOUN NN
# . . PUNCT .
# # # X ADD
# realdonaldtrump realdonaldtrump NOUN NN
# @realdonaldtrump @realdonaldtrump PROPN NNP
# ! ! PUNCT .
# @ben4appel @ben4appel PROPN NNP
# 🤣 🤣 PROPN NNP
# :) :) PUNCT :
# https://t.co/bsB6rVV7Yn https://t.co/bsb6rvv7yn NOUN NN

# %%
# python -m spacy download en_core_web_sm

# %%
#### 01 SpaCy ####
import pandas as pd
import spacy

df = pd.read_csv("testkorpus_divers_50.csv")
nlp = spacy.load("en_core_web_sm")
all_results = []

for idx, text in enumerate(df["text"], start=1):
    if pd.isna(text):
        continue
    doc = nlp(str(text))
    for token in doc:
        all_results.append({
            "post_id": idx,
            "word": token.text,
            "lemma": token.lemma_,
            "pos": token.pos_,
            "lemma_p": f"{token.lemma_}_{token.pos_}",
            "tag": token.tag_
        })

sp = pd.DataFrame(all_results)
sp.to_csv("testkorpus_divers_50_spacy.csv", index=False)
display(sp[310:360])
# der Code funktioniert; allerdings werden Emojis, @ und Post-spezifische Dinge nicht erkannt.
# Out:
#      post_id                                               word  \
# 310       16                                              skies
# 311       16                                               over
# 312       16                                               Iran
# 313       16                                                  .
# 314       16                                               Iran
# 315       16                                                had
# 316       16                                               good
# 317       16                                                sky
# 318       16                                           trackers
# 319       16                                                and
# 320       16                                              other
# 321       16                                          defensive
# 322       16                                          equipment
# 323       16                                                  ,
# 324       16                                                and
# 325       16                                             plenty
# 326       16                                                 of
# 327       16                                                 it
# 328       16                                                  ,
# 329       16                                                but
# 330       16                                                 it
# 331       16                                               does
# 332       16                                                n’t
# 333       16                                            compare
# 334       16                                                 to
# 335       16                                           American
# 336       16                                               made
# 337       16                                                  ,
# 338       16                                          conceived
# 339       16                                                  ,
# 340       16                                                and
# 341       16                                       manufactured
# 342       16                                                  “
# 343       16                                              stuff
# 344       16                                                  .
# 345       16                                                  ”
# 346       16                                             Nobody
# 347       16                                               does
# 348       16                                                 it
# 349       16                                             better
# 350       16                                               than
# 351       16                                                the
# 352       16                                               good
# 353       16                                                ol’
# 354       16                                                USA
# 355       16                                                  .
# 356       17  https://www.thegatewaypundit.com/2025/07/her-b...
# 357       18  https://www.foxnews.com/politics/hunter-biden-...
# 358       19                                                Via
# 359       19                                     @BreitbartNews
#
#                                                  lemma    pos  \
# 310                                                sky   NOUN
# 311                                               over    ADP
# 312                                               Iran  PROPN
# 313                                                  .  PUNCT
# 314                                               Iran  PROPN
# 315                                               have   VERB
# 316                                               good    ADJ
# 317                                                sky   NOUN
# 318                                            tracker   NOUN
# 319                                                and  CCONJ
# 320                                              other    ADJ
# 321                                          defensive    ADJ
# 322                                          equipment   NOUN
# 323                                                  ,  PUNCT
# 324                                                and  CCONJ
# 325                                             plenty   NOUN
# 326                                                 of    ADP
# 327                                                 it   PRON
# 328                                                  ,  PUNCT
# 329                                                but  CCONJ
# 330                                                 it   PRON
# 331                                                 do    AUX
# 332                                                not   PART
# 333                                            compare   VERB
# 334                                                 to    ADP
# 335                                           American  PROPN
# 336                                               make   VERB
# 337                                                  ,  PUNCT
# 338                                           conceive   VERB
# 339                                                  ,  PUNCT
# 340                                                and  CCONJ
# 341                                        manufacture   VERB
# 342                                                  "  PUNCT
# 343                                              stuff   NOUN
# 344                                                  .  PUNCT
# 345                                                  "  PUNCT
# 346                                             nobody   PRON
# 347                                                 do   VERB
# 348                                                 it   PRON
# 349                                               well    ADJ
# 350                                               than    ADP
# 351                                                the    DET
# 352                                               good    ADJ
# 353                                                ol’    ADJ
# 354                                                USA  PROPN
# 355                                                  .  PUNCT
# 356  https://www.thegatewaypundit.com/2025/07/her-b...  PROPN
# 357  https://www.foxnews.com/politics/hunter-biden-...  PROPN
# 358                                                Via  PROPN
# 359                                     @BreitbartNews  PROPN
#
#                                                lemma_p  tag
# 310                                           sky_NOUN  NNS
# 311                                           over_ADP   IN
# 312                                         Iran_PROPN  NNP
# 313                                            ._PUNCT    .
# 314                                         Iran_PROPN  NNP
# 315                                          have_VERB  VBD
# 316                                           good_ADJ   JJ
# 317                                           sky_NOUN   NN
# 318                                       tracker_NOUN  NNS
# 319                                          and_CCONJ   CC
# 320                                          other_ADJ   JJ
# 321                                      defensive_ADJ   JJ
# 322                                     equipment_NOUN   NN
# 323                                            ,_PUNCT    ,
# 324                                          and_CCONJ   CC
# 325                                        plenty_NOUN   NN
# 326                                             of_ADP   IN
# 327                                            it_PRON  PRP
# 328                                            ,_PUNCT    ,
# 329                                          but_CCONJ   CC
# 330                                            it_PRON  PRP
# 331                                             do_AUX  VBZ
# 332                                           not_PART   RB
# 333                                       compare_VERB   VB
# 334                                             to_ADP   IN
# 335                                     American_PROPN  NNP
# 336                                          make_VERB  VBN
# 337                                            ,_PUNCT    ,
# 338                                      conceive_VERB  VBN
# 339                                            ,_PUNCT    ,
# 340                                          and_CCONJ   CC
# 341                                   manufacture_VERB  VBN
# 342                                            "_PUNCT   ``
# 343                                         stuff_NOUN   NN
# 344                                            ._PUNCT    .
# 345                                            "_PUNCT   ''
# 346                                        nobody_PRON   NN
# 347                                            do_VERB  VBZ
# 348                                            it_PRON  PRP
# 349                                           well_ADJ  JJR
# 350                                           than_ADP   IN
# 351                                            the_DET   DT
# 352                                           good_ADJ   JJ
# 353                                            ol’_ADJ   JJ
# 354                                          USA_PROPN  NNP
# 355                                            ._PUNCT    .
# 356  https://www.thegatewaypundit.com/2025/07/her-b...  NNP
# 357  https://www.foxnews.com/politics/hunter-biden-...  NNP
# 358                                          Via_PROPN  NNP
# 359                               @BreitbartNews_PROPN  NNP

# %%
import pandas as pd
sp = pd.read_csv("testkorpus_divers_50_spacy.csv")
display(sp[200:215])
# Out:
#      post_id           word          lemma    pos              lemma_p  tag
# 200       11              #              #    SYM                #_SYM    $
# 201       11  MadeInAmerica  MadeInAmerica  PROPN  MadeInAmerica_PROPN  NNP
# 202       11          event          event   NOUN           event_NOUN   NN
# 203       11              ,              ,  PUNCT              ,_PUNCT    ,
# 204       11          right          right    ADV            right_ADV   RB
# 205       11           here           here    ADV             here_ADV   RB
# 206       11             at             at    ADP               at_ADP   IN
# 207       11            the            the    DET              the_DET   DT
# 208       11    @WhiteHouse    @whitehouse   NOUN     @whitehouse_NOUN   NN
# 209       11              !              !  PUNCT              !_PUNCT    .
# 210       11             If             if  SCONJ             if_SCONJ   IN
# 211       11             it             it   PRON              it_PRON  PRP
# 212       11             is             be    AUX               be_AUX  VBZ
# 213       11           MADE           make   VERB            make_VERB  VBN
# 214       11             IN             in    ADP               in_ADP   IN

# %%
display(sp[1200:1242])
# Out:
#       post_id            word           lemma    pos               lemma_p  \
# 1200       50             ALL             all   PRON              all_PRON
# 1201       50              of              of    ADP                of_ADP
# 1202       50            them            they   PRON             they_PRON
# 1203       50            were              be    AUX                be_AUX
# 1204       50        released         release   VERB          release_VERB
# 1205       50            into            into    ADP              into_ADP
# 1206       50             our             our   PRON              our_PRON
# 1207       50         Country         Country  PROPN         Country_PROPN
# 1208       50               .               .  PUNCT               ._PUNCT
# 1209       50          Thanks           thank   NOUN            thank_NOUN
# 1210       50              to              to    ADP                to_ADP
# 1211       50             the             the    DET               the_DET
# 1212       50           Trump           Trump  PROPN           Trump_PROPN
# 1213       50  Administration  Administration  PROPN  Administration_PROPN
# 1214       50        Policies        Policies  PROPN        Policies_PROPN
# 1215       50               ,               ,  PUNCT               ,_PUNCT
# 1216       50             the             the    DET               the_DET
# 1217       50          Border          Border  PROPN          Border_PROPN
# 1218       50              is              be    AUX                be_AUX
# 1219       50          CLOSED          closed    ADJ            closed_ADJ
# 1220       50              to              to    ADP                to_ADP
# 1221       50             all             all    DET               all_DET
# 1222       50         Illegal         Illegal  PROPN         Illegal_PROPN
# 1223       50      Immigrants      Immigrants  PROPN      Immigrants_PROPN
# 1224       50               .               .  PUNCT               ._PUNCT
# 1225       50          Anyone          anyone   PRON           anyone_PRON
# 1226       50             who             who   PRON              who_PRON
# 1227       50           tries             try   VERB              try_VERB
# 1228       50              to              to   PART               to_PART
# 1229       50       illegally       illegally    ADV         illegally_ADV
# 1230       50           enter           enter   VERB            enter_VERB
# 1231       50             the             the    DET               the_DET
# 1232       50          U.S.A.          U.S.A.  PROPN          U.S.A._PROPN
# 1233       50            will            will    AUX              will_AUX
# 1234       50            face            face   VERB             face_VERB
# 1235       50     significant     significant    ADJ       significant_ADJ
# 1236       50        criminal        criminal    ADJ          criminal_ADJ
# 1237       50       penalties         penalty   NOUN          penalty_NOUN
# 1238       50             and             and  CCONJ             and_CCONJ
# 1239       50       immediate       immediate    ADJ         immediate_ADJ
# 1240       50     deportation     deportation   NOUN      deportation_NOUN
# 1241       50               .               .  PUNCT               ._PUNCT
#
#        tag
# 1200    DT
# 1201    IN
# 1202   PRP
# 1203   VBD
# 1204   VBN
# 1205    IN
# 1206  PRP$
# 1207   NNP
# 1208     .
# 1209   NNS
# 1210    IN
# 1211    DT
# 1212   NNP
# 1213   NNP
# 1214  NNPS
# 1215     ,
# 1216    DT
# 1217   NNP
# 1218   VBZ
# 1219    JJ
# 1220    IN
# 1221    DT
# 1222   NNP
# 1223  NNPS
# 1224     .
# 1225    NN
# 1226    WP
# 1227   VBZ
# 1228    TO
# 1229    RB
# 1230    VB
# 1231    DT
# 1232   NNP
# 1233    MD
# 1234    VB
# 1235    JJ
# 1236    JJ
# 1237   NNS
# 1238    CC
# 1239    JJ
# 1240    NN
# 1241     .

# %%
display(sp[70:110])
# Out:
#      post_id       word      lemma    pos          lemma_p  tag
# 70         5         ’s         ’s   PART          ’s_PART  POS
# 71         5     Office     office   NOUN      office_NOUN   NN
# 72         5     Shreds      shred   VERB       shred_VERB  VBZ
# 73         5        NBC        NBC  PROPN        NBC_PROPN  NNP
# 74         5         ’s         ’s   PART          ’s_PART  POS
# 75         5      Chuck      Chuck  PROPN      Chuck_PROPN  NNP
# 76         5       Todd       Todd  PROPN       Todd_PROPN  NNP
# 77         5        For        for    ADP          for_ADP   IN
# 78         5          ‘          '  PUNCT          '_PUNCT   ``
# 79         5  Deceptive  Deceptive  PROPN  Deceptive_PROPN  NNP
# 80         5    Editing    editing   NOUN     editing_NOUN   NN
# 81         5          ’          '  PUNCT          '_PUNCT   ''
# 82         5         Of         of    ADP           of_ADP   IN
# 83         5       Barr       Barr  PROPN       Barr_PROPN  NNP
# 84         5         ’s         ’s   PART          ’s_PART  POS
# 85         5   Comments    comment   NOUN     comment_NOUN  NNS
# 86         5         \n         \n  SPACE         \n_SPACE  _SP
# 87         5         On         on    ADP           on_ADP   IN
# 88         5          “          "  PUNCT          "_PUNCT   ``
# 89         5       Meet       Meet  PROPN       Meet_PROPN  NNP
# 90         5        The        The  PROPN        The_PROPN  NNP
# 91         5      Press      Press  PROPN      Press_PROPN  NNP
# 92         5          ,          ,  PUNCT          ,_PUNCT    ,
# 93         5          ”          "  PUNCT          "_PUNCT   ''
# 94         5       Todd       todd    ADJ         todd_ADJ   JJ
# 95         5          …          …  PUNCT          …_PUNCT  NFP
# 96         6         RT         RT  PROPN         RT_PROPN  NNP
# 97         6                        SPACE           _SPACE  _SP
# 98         6  @MagaGlam  @magaglam    SYM    @magaglam_SYM  SYM
# 99         6          🇺          🇺      X              🇺_X  ADD
# 100        6          🇸          🇸   NOUN           🇸_NOUN  NNS
# 101        6          ♥          ♥  PROPN          ♥_PROPN  NNP
# 102        6          ️          ️      X              ️_X  ADD
# 103        6      Bring      bring   VERB       bring_VERB   VB
# 104        6       Back       back    ADP         back_ADP   RP
# 105        6                        SPACE           _SPACE  _SP
# 106        6      Trump      Trump  PROPN      Trump_PROPN  NNP
# 107        6                        SPACE           _SPACE  _SP
# 108        6          💙          💙  PROPN          💙_PROPN  NNP
# 109        6          🇺          🇺   NOUN           🇺_NOUN  NNS

# %%
sp.shape # Wie viele Tags wurden vergeben?
# Out:
# (1242, 6)

# %%
#### 02 SpaCy ### mit ganzen Sätzen zum Vergleichen ##
import pandas as pd
import spacy

df = pd.read_csv("testkorpus_divers_50.csv")

# python -m spacy download en_core_web_sm
nlp = spacy.load("en_core_web_sm")
all_results = []

for idx, row in df.iterrows():
    text = row["text"]
    if pd.isna(text) or str(text).strip() == "":
        continue
    
    doc = nlp(str(text))
    
    for sent_id, sent in enumerate(doc.sents, start=1):
        sent_text = sent.text
        for token_id, token in enumerate(sent, start=1):
            all_results.append({
                "post_id": idx + 1,
                "date": row["date"],
                "sentence_id": sent_id,
                "token_id": token_id,
                "sentence_text": sent_text,
                "word": token.text,
                "lemma": token.lemma_,
                "pos": token.pos_,
                "lemma_p": f"{token.lemma_}_{token.pos_}"
            })

sp2 = pd.DataFrame(all_results)
sp2.to_csv("testkorpus_divers_50_spacy_2.csv", index=False, encoding="utf-8")
display(sp2[500:555])
# Out:
#      post_id        date  sentence_id  token_id  \
# 500       25  2025-03-12            1        19
# 501       25  2025-03-12            1        20
# 502       25  2025-03-12            1        21
# 503       25  2025-03-12            1        22
# 504       25  2025-03-12            1        23
# 505       25  2025-03-12            1        24
# 506       25  2025-03-12            1        25
# 507       25  2025-03-12            1        26
# 508       25  2025-03-12            1        27
# 509       25  2025-03-12            1        28
# 510       25  2025-03-12            1        29
# 511       25  2025-03-12            1        30
# 512       25  2025-03-12            2         1
# 513       25  2025-03-12            2         2
# 514       25  2025-03-12            2         3
# 515       25  2025-03-12            2         4
# 516       25  2025-03-12            2         5
# 517       25  2025-03-12            2         6
# 518       25  2025-03-12            2         7
# 519       25  2025-03-12            2         8
# 520       25  2025-03-12            2         9
# 521       25  2025-03-12            2        10
# 522       25  2025-03-12            2        11
# 523       25  2025-03-12            2        12
# 524       25  2025-03-12            2        13
# 525       25  2025-03-12            2        14
# 526       25  2025-03-12            2        15
# 527       25  2025-03-12            2        16
# 528       25  2025-03-12            2        17
# 529       25  2025-03-12            2        18
# 530       25  2025-03-12            2        19
# 531       25  2025-03-12            2        20
# 532       25  2025-03-12            2        21
# 533       27  2011-09-06            1         1
# 534       27  2011-09-06            1         2
# 535       27  2011-09-06            1         3
# 536       27  2011-09-06            1         4
# 537       27  2011-09-06            1         5
# 538       27  2011-09-06            1         6
# 539       27  2011-09-06            1         7
# 540       27  2011-09-06            1         8
# 541       27  2011-09-06            1         9
# 542       27  2011-09-06            1        10
# 543       27  2011-09-06            1        11
# 544       27  2011-09-06            1        12
# 545       27  2011-09-06            1        13
# 546       27  2011-09-06            1        14
# 547       27  2011-09-06            1        15
# 548       27  2011-09-06            1        16
# 549       27  2011-09-06            1        17
# 550       27  2011-09-06            1        18
# 551       27  2011-09-06            1        19
# 552       27  2011-09-06            1        20
# 553       27  2011-09-06            1        21
# 554       27  2011-09-06            1        22
#
#                                          sentence_text                  word  \
# 500  The United States of America is going to take ...                    by
# 501  The United States of America is going to take ...                 other
# 502  The United States of America is going to take ...             countries
# 503  The United States of America is going to take ...                   and
# 504  The United States of America is going to take ...                     ,
# 505  The United States of America is going to take ...               frankly
# 506  The United States of America is going to take ...                     ,
# 507  The United States of America is going to take ...                    by
# 508  The United States of America is going to take ...           incompetent
# 509  The United States of America is going to take ...                  U.S.
# 510  The United States of America is going to take ...            leadership
# 511  The United States of America is going to take ...                     .
# 512  We're going to take back our wealth and we're ...                    We
# 513  We're going to take back our wealth and we're ...                   're
# 514  We're going to take back our wealth and we're ...                 going
# 515  We're going to take back our wealth and we're ...                    to
# 516  We're going to take back our wealth and we're ...                  take
# 517  We're going to take back our wealth and we're ...                  back
# 518  We're going to take back our wealth and we're ...                   our
# 519  We're going to take back our wealth and we're ...                wealth
# 520  We're going to take back our wealth and we're ...                   and
# 521  We're going to take back our wealth and we're ...                    we
# 522  We're going to take back our wealth and we're ...                   're
# 523  We're going to take back our wealth and we're ...                  take
# 524  We're going to take back our wealth and we're ...                  back
# 525  We're going to take back our wealth and we're ...                     a
# 526  We're going to take back our wealth and we're ...                   lot
# 527  We're going to take back our wealth and we're ...                    of
# 528  We're going to take back our wealth and we're ...                   the
# 529  We're going to take back our wealth and we're ...             companies
# 530  We're going to take back our wealth and we're ...                  that
# 531  We're going to take back our wealth and we're ...                  left
# 532  We're going to take back our wealth and we're ...                     …
# 533  RT  @mrddmiaIf Trump didn't  incite the Januar...                    RT
# 534  RT  @mrddmiaIf Trump didn't  incite the Januar...
# 535  RT  @mrddmiaIf Trump didn't  incite the Januar...            @mrddmiaIf
# 536  RT  @mrddmiaIf Trump didn't  incite the Januar...                 Trump
# 537  RT  @mrddmiaIf Trump didn't  incite the Januar...                   did
# 538  RT  @mrddmiaIf Trump didn't  incite the Januar...                   n't
# 539  RT  @mrddmiaIf Trump didn't  incite the Januar...
# 540  RT  @mrddmiaIf Trump didn't  incite the Januar...                incite
# 541  RT  @mrddmiaIf Trump didn't  incite the Januar...                   the
# 542  RT  @mrddmiaIf Trump didn't  incite the Januar...               January
# 543  RT  @mrddmiaIf Trump didn't  incite the Januar...                   6th
# 544  RT  @mrddmiaIf Trump didn't  incite the Januar...                  riot
# 545  RT  @mrddmiaIf Trump didn't  incite the Januar...                     ,
# 546  RT  @mrddmiaIf Trump didn't  incite the Januar...                  what
# 547  RT  @mrddmiaIf Trump didn't  incite the Januar...                    's
# 548  RT  @mrddmiaIf Trump didn't  incite the Januar...                   the
# 549  RT  @mrddmiaIf Trump didn't  incite the Januar...                actual
# 550  RT  @mrddmiaIf Trump didn't  incite the Januar...                 crime
# 551  RT  @mrddmiaIf Trump didn't  incite the Januar...                   and
# 552  RT  @mrddmiaIf Trump didn't  incite the Januar...
# 553  RT  @mrddmiaIf Trump didn't  incite the Januar...  conspiracy?Objecting
# 554  RT  @mrddmiaIf Trump didn't  incite the Januar...                    to
#
#                   lemma    pos                  lemma_p
# 500                  by    ADP                   by_ADP
# 501               other    ADJ                other_ADJ
# 502             country   NOUN             country_NOUN
# 503                 and  CCONJ                and_CCONJ
# 504                   ,  PUNCT                  ,_PUNCT
# 505             frankly    ADV              frankly_ADV
# 506                   ,  PUNCT                  ,_PUNCT
# 507                  by    ADP                   by_ADP
# 508         incompetent    ADJ          incompetent_ADJ
# 509                U.S.  PROPN               U.S._PROPN
# 510          leadership   NOUN          leadership_NOUN
# 511                   .  PUNCT                  ._PUNCT
# 512                  we   PRON                  we_PRON
# 513                  be    AUX                   be_AUX
# 514                  go   VERB                  go_VERB
# 515                  to   PART                  to_PART
# 516                take   VERB                take_VERB
# 517                back    ADV                 back_ADV
# 518                 our   PRON                 our_PRON
# 519              wealth   NOUN              wealth_NOUN
# 520                 and  CCONJ                and_CCONJ
# 521                  we   PRON                  we_PRON
# 522                  be    AUX                   be_AUX
# 523                take   VERB                take_VERB
# 524                back    ADV                 back_ADV
# 525                   a    DET                    a_DET
# 526                 lot   NOUN                 lot_NOUN
# 527                  of    ADP                   of_ADP
# 528                 the    DET                  the_DET
# 529             company   NOUN             company_NOUN
# 530                that   PRON                that_PRON
# 531               leave   VERB               leave_VERB
# 532                   …  PUNCT                  …_PUNCT
# 533                  RT  PROPN                 RT_PROPN
# 534                      SPACE                   _SPACE
# 535          @mrddmiaIf  PROPN         @mrddmiaIf_PROPN
# 536               Trump  PROPN              Trump_PROPN
# 537                  do    AUX                   do_AUX
# 538                 not   PART                 not_PART
# 539                      SPACE                   _SPACE
# 540              incite   VERB              incite_VERB
# 541                 the    DET                  the_DET
# 542             January  PROPN            January_PROPN
# 543                 6th   NOUN                 6th_NOUN
# 544                riot   NOUN                riot_NOUN
# 545                   ,  PUNCT                  ,_PUNCT
# 546                what   PRON                what_PRON
# 547                  be    AUX                   be_AUX
# 548                 the    DET                  the_DET
# 549              actual    ADJ               actual_ADJ
# 550               crime   NOUN               crime_NOUN
# 551                 and  CCONJ                and_CCONJ
# 552                      SPACE                   _SPACE
# 553  conspiracy?objecte   VERB  conspiracy?objecte_VERB
# 554                  to    ADP                   to_ADP

# %%
import pandas as pd
sp2 = pd.read_csv("testkorpus_divers_50_spacy_2.csv")
display(sp2[70:110])
# Out:
#      post_id        date  sentence_id  token_id  \
# 70         5  2020-05-11            1         7
# 71         5  2020-05-11            1         8
# 72         5  2020-05-11            1         9
# 73         5  2020-05-11            1        10
# 74         5  2020-05-11            1        11
# 75         5  2020-05-11            1        12
# 76         5  2020-05-11            1        13
# 77         5  2020-05-11            1        14
# 78         5  2020-05-11            1        15
# 79         5  2020-05-11            1        16
# 80         5  2020-05-11            1        17
# 81         5  2020-05-11            1        18
# 82         5  2020-05-11            2         1
# 83         5  2020-05-11            2         2
# 84         5  2020-05-11            2         3
# 85         5  2020-05-11            2         4
# 86         5  2020-05-11            2         5
# 87         5  2020-05-11            2         6
# 88         5  2020-05-11            2         7
# 89         5  2020-05-11            2         8
# 90         5  2020-05-11            2         9
# 91         5  2020-05-11            2        10
# 92         5  2020-05-11            2        11
# 93         5  2020-05-11            2        12
# 94         5  2020-05-11            2        13
# 95         5  2020-05-11            2        14
# 96         6  2011-09-07            1         1
# 97         6  2011-09-07            1         2
# 98         6  2011-09-07            1         3
# 99         6  2011-09-07            1         4
# 100        6  2011-09-07            1         5
# 101        6  2011-09-07            1         6
# 102        6  2011-09-07            1         7
# 103        6  2011-09-07            1         8
# 104        6  2011-09-07            1         9
# 105        6  2011-09-07            1        10
# 106        6  2011-09-07            1        11
# 107        6  2011-09-07            1        12
# 108        6  2011-09-07            1        13
# 109        6  2011-09-07            1        14
#
#                                          sentence_text       word      lemma  \
# 70   RT @darhar981: Attorney General Barr’s Office ...         ’s         ’s
# 71   RT @darhar981: Attorney General Barr’s Office ...     Office     office
# 72   RT @darhar981: Attorney General Barr’s Office ...     Shreds      shred
# 73   RT @darhar981: Attorney General Barr’s Office ...        NBC        NBC
# 74   RT @darhar981: Attorney General Barr’s Office ...         ’s         ’s
# 75   RT @darhar981: Attorney General Barr’s Office ...      Chuck      Chuck
# 76   RT @darhar981: Attorney General Barr’s Office ...       Todd       Todd
# 77   RT @darhar981: Attorney General Barr’s Office ...        For        for
# 78   RT @darhar981: Attorney General Barr’s Office ...          ‘          '
# 79   RT @darhar981: Attorney General Barr’s Office ...  Deceptive  Deceptive
# 80   RT @darhar981: Attorney General Barr’s Office ...    Editing    editing
# 81   RT @darhar981: Attorney General Barr’s Office ...          ’          '
# 82     Of Barr’s Comments \nOn “Meet The Press,” Todd…         Of         of
# 83     Of Barr’s Comments \nOn “Meet The Press,” Todd…       Barr       Barr
# 84     Of Barr’s Comments \nOn “Meet The Press,” Todd…         ’s         ’s
# 85     Of Barr’s Comments \nOn “Meet The Press,” Todd…   Comments    comment
# 86     Of Barr’s Comments \nOn “Meet The Press,” Todd…         \n         \n
# 87     Of Barr’s Comments \nOn “Meet The Press,” Todd…         On         on
# 88     Of Barr’s Comments \nOn “Meet The Press,” Todd…          “          "
# 89     Of Barr’s Comments \nOn “Meet The Press,” Todd…       Meet       Meet
# 90     Of Barr’s Comments \nOn “Meet The Press,” Todd…        The        The
# 91     Of Barr’s Comments \nOn “Meet The Press,” Todd…      Press      Press
# 92     Of Barr’s Comments \nOn “Meet The Press,” Todd…          ,          ,
# 93     Of Barr’s Comments \nOn “Meet The Press,” Todd…          ”          "
# 94     Of Barr’s Comments \nOn “Meet The Press,” Todd…       Todd       todd
# 95     Of Barr’s Comments \nOn “Meet The Press,” Todd…          …          …
# 96            RT  @MagaGlam🇺🇸♥️ Bring Back  Trump  💙🇺🇸         RT         RT
# 97            RT  @MagaGlam🇺🇸♥️ Bring Back  Trump  💙🇺🇸
# 98            RT  @MagaGlam🇺🇸♥️ Bring Back  Trump  💙🇺🇸  @MagaGlam  @magaglam
# 99            RT  @MagaGlam🇺🇸♥️ Bring Back  Trump  💙🇺🇸          🇺          🇺
# 100           RT  @MagaGlam🇺🇸♥️ Bring Back  Trump  💙🇺🇸          🇸          🇸
# 101           RT  @MagaGlam🇺🇸♥️ Bring Back  Trump  💙🇺🇸          ♥          ♥
# 102           RT  @MagaGlam🇺🇸♥️ Bring Back  Trump  💙🇺🇸          ️          ️
# 103           RT  @MagaGlam🇺🇸♥️ Bring Back  Trump  💙🇺🇸      Bring      bring
# 104           RT  @MagaGlam🇺🇸♥️ Bring Back  Trump  💙🇺🇸       Back       back
# 105           RT  @MagaGlam🇺🇸♥️ Bring Back  Trump  💙🇺🇸
# 106           RT  @MagaGlam🇺🇸♥️ Bring Back  Trump  💙🇺🇸      Trump      Trump
# 107           RT  @MagaGlam🇺🇸♥️ Bring Back  Trump  💙🇺🇸
# 108           RT  @MagaGlam🇺🇸♥️ Bring Back  Trump  💙🇺🇸          💙          💙
# 109           RT  @MagaGlam🇺🇸♥️ Bring Back  Trump  💙🇺🇸          🇺          🇺
#
#        pos          lemma_p
# 70    PART          ’s_PART
# 71    NOUN      office_NOUN
# 72    VERB       shred_VERB
# 73   PROPN        NBC_PROPN
# 74    PART          ’s_PART
# 75   PROPN      Chuck_PROPN
# 76   PROPN       Todd_PROPN
# 77     ADP          for_ADP
# 78   PUNCT          '_PUNCT
# 79   PROPN  Deceptive_PROPN
# 80    NOUN     editing_NOUN
# 81   PUNCT          '_PUNCT
# 82     ADP           of_ADP
# 83   PROPN       Barr_PROPN
# 84    PART          ’s_PART
# 85    NOUN     comment_NOUN
# 86   SPACE         \n_SPACE
# 87     ADP           on_ADP
# 88   PUNCT          "_PUNCT
# 89   PROPN       Meet_PROPN
# 90   PROPN        The_PROPN
# 91   PROPN      Press_PROPN
# 92   PUNCT          ,_PUNCT
# 93   PUNCT          "_PUNCT
# 94     ADJ         todd_ADJ
# 95   PUNCT          …_PUNCT
# 96   PROPN         RT_PROPN
# 97   SPACE           _SPACE
# 98     SYM    @magaglam_SYM
# 99       X              🇺_X
# 100   NOUN           🇸_NOUN
# 101  PROPN          ♥_PROPN
# 102      X              ️_X
# 103   VERB       bring_VERB
# 104    ADP         back_ADP
# 105  SPACE           _SPACE
# 106  PROPN      Trump_PROPN
# 107  SPACE           _SPACE
# 108  PROPN          💙_PROPN
# 109   NOUN           🇺_NOUN

# %%
sp2.shape
# Out:
# (1242, 9)

# %%
#### SpaCy mit Twitter ####
import pandas as pd
import spacy
from spacy.tokenizer import Tokenizer
import re

def create_twitter_tokenizer(nlp):
    # Erweiterte Infix-Regel für Hashtags und Mentions (z.B. #NLP, @user)
    infix_re = spacy.util.compile_infix_regex(
        nlp.Defaults.infixes + [r'(?<=\w)[#@](?=\w)']
    )
    return Tokenizer(nlp.vocab, infix_finditer=infix_re.finditer)

df = pd.read_csv("testkorpus_divers_50.csv")
nlp = spacy.load("en_core_web_sm")
nlp.tokenizer = create_twitter_tokenizer(nlp)

all_results = []

for idx, text in enumerate(df["text"], start=1):
    if pd.isna(text):
        continue
    doc = nlp(str(text))
    for token in doc:
        all_results.append({
            "post_id": idx,
            "word": token.text,
            "lemma": token.lemma_,
            "pos": token.pos_,
            "lemma_p": f"{token.lemma_}_{token.pos_}"
        })

spt = pd.DataFrame(all_results)
spt.to_csv("testkorpus_divers_50_spacy_twitter.csv", index=False, encoding="utf-8")
display(spt[450:500])
# Out:
#      post_id                     word                    lemma    pos  \
# 450       21             https://t.co             https://t.co  PROPN
# 451       21                        /                        /    SYM
# 452       21               v6z46rUDtg               v6z46rUDtg  PROPN
# 453       22                 Congress                 Congress  PROPN
# 454       22                     must                     must    AUX
# 455       22                  approve                  approve   VERB
# 456       22                      the                      the    DET
# 457       22                    deal,                    deal,   NOUN
# 458       22                  without                  without    ADP
# 459       22                      all                      all   PRON
# 460       22                       of                       of    ADP
# 461       22                      the                      the    DET
# 462       22                nonsense,                nonsense,   NOUN
# 463       22                   today.                   today.   NOUN
# 464       22                      The                      the   PRON
# 465       22                   longer                     long    ADV
# 466       22                       it                       it   PRON
# 467       22                   takes,                   takes,   NOUN
# 468       22                      the                      the   PRON
# 469       22                   harder                     hard    ADJ
# 470       22                       it                       it   PRON
# 471       22                     will                     will    AUX
# 472       22                       be                       be    AUX
# 473       22                       to                       to   PART
# 474       22                    start                    start   VERB
# 475       22                       up                       up    ADP
# 476       22                      our                      our   PRON
# 477       22                 economy.                 economy.   NOUN
# 478       22                      Our                      our   PRON
# 479       22                  workers                   worker   NOUN
# 480       22                     will                     will    AUX
# 481       22                       be                       be    AUX
# 482       22                    hurt!                    hurt!   VERB
# 483       23  https://justthenews.com  https://justthenews.com      X
# 484       23                        /                        /    SYM
# 485       23                 politics                  politic   NOUN
# 486       23                        -                        -  PUNCT
# 487       23                   policy                   policy   NOUN
# 488       23                        /                        /    SYM
# 489       23                      all                      all   PRON
# 490       23                        -                        -  PUNCT
# 491       23                   things                    thing   NOUN
# 492       23                        -                        -  PUNCT
# 493       23                    trump                    trump   NOUN
# 494       23                        /                        /    SYM
# 495       23                    trump                    trump   NOUN
# 496       23                        -                        -  PUNCT
# 497       23                   serves                    serve   NOUN
# 498       23                        -                        -  PUNCT
# 499       23                    meals                     meal   NOUN
#
#                        lemma_p
# 450         https://t.co_PROPN
# 451                      /_SYM
# 452           v6z46rUDtg_PROPN
# 453             Congress_PROPN
# 454                   must_AUX
# 455               approve_VERB
# 456                    the_DET
# 457                 deal,_NOUN
# 458                without_ADP
# 459                   all_PRON
# 460                     of_ADP
# 461                    the_DET
# 462             nonsense,_NOUN
# 463                today._NOUN
# 464                   the_PRON
# 465                   long_ADV
# 466                    it_PRON
# 467                takes,_NOUN
# 468                   the_PRON
# 469                   hard_ADJ
# 470                    it_PRON
# 471                   will_AUX
# 472                     be_AUX
# 473                    to_PART
# 474                 start_VERB
# 475                     up_ADP
# 476                   our_PRON
# 477              economy._NOUN
# 478                   our_PRON
# 479                worker_NOUN
# 480                   will_AUX
# 481                     be_AUX
# 482                 hurt!_VERB
# 483  https://justthenews.com_X
# 484                      /_SYM
# 485               politic_NOUN
# 486                    -_PUNCT
# 487                policy_NOUN
# 488                      /_SYM
# 489                   all_PRON
# 490                    -_PUNCT
# 491                 thing_NOUN
# 492                    -_PUNCT
# 493                 trump_NOUN
# 494                      /_SYM
# 495                 trump_NOUN
# 496                    -_PUNCT
# 497                 serve_NOUN
# 498                    -_PUNCT
# 499                  meal_NOUN

# %%
import pandas as pd
spt = pd.read_csv("testkorpus_divers_50_spacy_twitter.csv")
display(spt[70:110])
# Out:
#      post_id             word           lemma    pos              lemma_p
# 70         5          Press,”         Press,”   NOUN         Press,”_NOUN
# 71         5             Todd            Todd  PROPN           Todd_PROPN
# 72         5                …               …  PUNCT              …_PUNCT
# 73         6               RT              RT  PROPN             RT_PROPN
# 74         6                                   SPACE               _SPACE
# 75         6        @MagaGlam       @magaglam    SYM        @magaglam_SYM
# 76         6                🇺               🇺      X                  🇺_X
# 77         6                🇸               🇸   NOUN               🇸_NOUN
# 78         6                ♥               ♥  PROPN              ♥_PROPN
# 79         6                ️               ️      X                  ️_X
# 80         6            Bring           bring   VERB           bring_VERB
# 81         6             Back            back    ADP             back_ADP
# 82         6                                   SPACE               _SPACE
# 83         6            Trump           Trump  PROPN          Trump_PROPN
# 84         6                                   SPACE               _SPACE
# 85         6                💙               💙  PROPN              💙_PROPN
# 86         6                🇺               🇺   NOUN               🇺_NOUN
# 87         6                🇸               🇸      X                  🇸_X
# 88         8              The             the    DET              the_DET
# 89         8              CBP             CBP  PROPN            CBP_PROPN
# 90         8             Home            Home  PROPN           Home_PROPN
# 91         8              App             App  PROPN            App_PROPN
# 92         8               is              be    AUX               be_AUX
# 93         8              now             now    ADV              now_ADV
# 94         8        available       available    ADJ        available_ADJ
# 95         8           across          across    ADP           across_ADP
# 96         8              all             all    DET              all_DET
# 97         8           mobile          mobile    ADJ           mobile_ADJ
# 98         8              App             App  PROPN            App_PROPN
# 99         8          Stores!         stores!   NOUN         stores!_NOUN
# 100        9  Congratulations  congratulation   NOUN  congratulation_NOUN
# 101        9               to              to    ADP               to_ADP
# 102        9          Mariano         Mariano  PROPN        Mariano_PROPN
# 103        9           Rivera          Rivera  PROPN         Rivera_PROPN
# 104        9               on              on    ADP               on_ADP
# 105        9      unanimously     unanimously    ADV      unanimously_ADV
# 106        9            being              be    AUX               be_AUX
# 107        9          elected           elect   VERB           elect_VERB
# 108        9               to              to    ADP               to_ADP
# 109        9              the             the    DET              the_DET

# %%
spt.shape
# Out:
# (1244, 5)

# %% [markdown]
# #### Fazit zu SpaCy:
# - Hashes oft getrennt und dann falsch getrennt oder Hashes als SYM und Folgendes als PROPN
# - @ meistens als X oder NOUN getaggt, aber richtig beibehalten
# - Barr's getrennt als Barr PROPN und 's als PART
# - Emojis getrennt und als Satz analysiert (ebenso wie Hash und @ als Satz analysiert werden), falsch
# - Lemmatisierung nicht so gut
# - LL.Bean richtig erkannt
# - Tagging nicht ganz richtig
# #### spacy2:
# - shreds richtig als shred erkannt
# - besser lemmatisiert
# - Hashes gut getrennt, aber als Satz analysiert
# - Links gut beibehalten, Tagging komisch
# - trotzdem Problem mit Hash und @
# #### mit twitter:
# - Satzzeichen werden nicht richtig getrennt
# - schlechte Tokenisierung
# - @ und Hash gut
# - nicht alle Tags passen (z.B. Meet NOUN the DET press NOUN, USA als ADV)
# - Emojis nicht gut erkannt
# - manche Links werden zerhäkselt, manche nicht
# - Lemmatisierung gut

# %% [markdown]
# # Stanza
# https://huggingface.co/stanfordnlp/stanza-en

# %%
# !pip install stanza

# %%
#### das englische Modell für Stanza #### basierend auf UD
import pandas as pd
import stanza
stanza.download('en')  
nlp = stanza.Pipeline('en', processors='tokenize,pos,lemma', use_gpu=False)
df = pd.read_csv("testkorpus_divers_50.csv")

all_results = []

for idx, row in df.iterrows():
    text = row["text"]
    if pd.isna(text):
        continue
    doc = nlp(str(text))
    for sentence in doc.sentences:
        for token in sentence.tokens:
            word = token.text
            word_info = token.words[0]
            lemma = word_info.lemma
            pos = word_info.upos
            lemma_p = f"{lemma}_{pos}"
            
            all_results.append({
                "post_id": idx + 1,
                "date": row["date"],
                "text": text,
                "word": word,
                "lemma": lemma,
                "pos": pos,
                "lemma_p": lemma_p
            })

sta = pd.DataFrame(all_results)
sta.to_csv("testkorpus_divers_50_stanza.csv", index=False, encoding="utf-8")
display(sta[612:665])
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-09-13 13:51:13 INFO: Downloaded file to /Users/vivien/stanza_resources/resources.json
# 2025-09-13 13:51:13 INFO: Downloading default packages for language: en (English) ...
# 2025-09-13 13:51:16 INFO: File exists: /Users/vivien/stanza_resources/en/default.zip
# 2025-09-13 13:51:22 INFO: Finished downloading models and saved to /Users/vivien/stanza_resources
# 2025-09-13 13:51:22 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-09-13 13:56:22 INFO: Downloaded file to /Users/vivien/stanza_resources/resources.json
# 2025-09-13 13:56:22 WARNING: Language en package default expects mwt, which has been added
# 2025-09-13 13:56:23 INFO: Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# =================================
#
# 2025-09-13 13:56:23 INFO: Using device: cpu
# 2025-09-13 13:56:23 INFO: Loading: tokenize
# 2025-09-13 13:56:26 INFO: Loading: mwt
# 2025-09-13 13:56:26 INFO: Loading: pos
# 2025-09-13 13:56:29 INFO: Loading: lemma
# 2025-09-13 13:56:30 INFO: Done loading processors!
#      post_id        date                                               text  \
# 612       30  2014-09-01  ""@NPHerron: @realDonaldTrump For president #2...
# 613       30  2014-09-01  ""@NPHerron: @realDonaldTrump For president #2...
# 614       30  2014-09-01  ""@NPHerron: @realDonaldTrump For president #2...
# 615       30  2014-09-01  ""@NPHerron: @realDonaldTrump For president #2...
# 616       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 617       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 618       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 619       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 620       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 621       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 622       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 623       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 624       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 625       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 626       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 627       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 628       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 629       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 630       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 631       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 632       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 633       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 634       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 635       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 636       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 637       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 638       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 639       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 640       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 641       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 642       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 643       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 644       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 645       31  2013-07-17  The Zimmerman trial is over.  It is time to mo...
# 646       32  2020-11-07  RT @dbongino: The Polls Were More Wrong in 202...
# 647       32  2020-11-07  RT @dbongino: The Polls Were More Wrong in 202...
# 648       32  2020-11-07  RT @dbongino: The Polls Were More Wrong in 202...
# 649       32  2020-11-07  RT @dbongino: The Polls Were More Wrong in 202...
# 650       32  2020-11-07  RT @dbongino: The Polls Were More Wrong in 202...
# 651       32  2020-11-07  RT @dbongino: The Polls Were More Wrong in 202...
# 652       32  2020-11-07  RT @dbongino: The Polls Were More Wrong in 202...
# 653       32  2020-11-07  RT @dbongino: The Polls Were More Wrong in 202...
# 654       32  2020-11-07  RT @dbongino: The Polls Were More Wrong in 202...
# 655       32  2020-11-07  RT @dbongino: The Polls Were More Wrong in 202...
# 656       32  2020-11-07  RT @dbongino: The Polls Were More Wrong in 202...
# 657       32  2020-11-07  RT @dbongino: The Polls Were More Wrong in 202...
# 658       32  2020-11-07  RT @dbongino: The Polls Were More Wrong in 202...
# 659       32  2020-11-07  RT @dbongino: The Polls Were More Wrong in 202...
# 660       32  2020-11-07  RT @dbongino: The Polls Were More Wrong in 202...
# 661       33  2011-09-11  RT  @IStandWithTrump47November 5th can’t  come...
# 662       33  2011-09-11  RT  @IStandWithTrump47November 5th can’t  come...
# 663       33  2011-09-11  RT  @IStandWithTrump47November 5th can’t  come...
# 664       33  2011-09-11  RT  @IStandWithTrump47November 5th can’t  come...
#
#                            word                       lemma    pos  \
# 612                           #                           #    SYM
# 613                2016election                2016election  PROPN
# 614                           "                           "  PUNCT
# 615                           "                           "  PUNCT
# 616                         The                         the    DET
# 617                   Zimmerman                   Zimmerman  PROPN
# 618                       trial                       trial   NOUN
# 619                          is                          be    AUX
# 620                        over                        over    ADV
# 621                           .                           .  PUNCT
# 622                          It                          it   PRON
# 623                          is                          be    AUX
# 624                        time                        time   NOUN
# 625                          to                          to   PART
# 626                        move                        move   VERB
# 627                          on                          on    ADP
# 628                           .                           .  PUNCT
# 629                       While                       while  SCONJ
# 630                   Zimmerman                   Zimmerman  PROPN
# 631                          is                          be    AUX
# 632                          no                          no    DET
# 633                       angel                       angel   NOUN
# 634                           ,                           ,  PUNCT
# 635                          he                          he   PRON
# 636                         was                          be    AUX
# 637                   acquitted                     acquitt   VERB
# 638                         and                         and  CCONJ
# 639                      should                      should    AUX
# 640                          be                          be    AUX
# 641                        able                        able    ADJ
# 642                          to                          to   PART
# 643                        move                        move   VERB
# 644                          on                          on    ADP
# 645                           .                           .  PUNCT
# 646                          RT                          RT  PROPN
# 647                   @dbongino                   @dbongino  PROPN
# 648                           :                           :  PUNCT
# 649                         The                         the    DET
# 650                       Polls                       Polls  PROPN
# 651                        Were                          be    AUX
# 652                        More                        more    ADV
# 653                       Wrong                       wrong    ADJ
# 654                          in                          in    ADP
# 655                        2020                        2020    NUM
# 656                        Than                        then    ADV
# 657                          in                          in    ADP
# 658                        2016                        2016    NUM
# 659                          👇👇                          👇👇  PUNCT
# 660     https://t.co/LpepzKdlp1     https://t.co/LpepzKdlp1  PROPN
# 661                          RT                          RT  PROPN
# 662  @IStandWithTrump47November  @IStandWithTrump47November  PROPN
# 663                         5th                         5th   NOUN
# 664                       can’t                         can    AUX
#
#                               lemma_p
# 612                             #_SYM
# 613                2016election_PROPN
# 614                           "_PUNCT
# 615                           "_PUNCT
# 616                           the_DET
# 617                   Zimmerman_PROPN
# 618                        trial_NOUN
# 619                            be_AUX
# 620                          over_ADV
# 621                           ._PUNCT
# 622                           it_PRON
# 623                            be_AUX
# 624                         time_NOUN
# 625                           to_PART
# 626                         move_VERB
# 627                            on_ADP
# 628                           ._PUNCT
# 629                       while_SCONJ
# 630                   Zimmerman_PROPN
# 631                            be_AUX
# 632                            no_DET
# 633                        angel_NOUN
# 634                           ,_PUNCT
# 635                           he_PRON
# 636                            be_AUX
# 637                      acquitt_VERB
# 638                         and_CCONJ
# 639                        should_AUX
# 640                            be_AUX
# 641                          able_ADJ
# 642                           to_PART
# 643                         move_VERB
# 644                            on_ADP
# 645                           ._PUNCT
# 646                          RT_PROPN
# 647                   @dbongino_PROPN
# 648                           :_PUNCT
# 649                           the_DET
# 650                       Polls_PROPN
# 651                            be_AUX
# 652                          more_ADV
# 653                         wrong_ADJ
# 654                            in_ADP
# 655                          2020_NUM
# 656                          then_ADV
# 657                            in_ADP
# 658                          2016_NUM
# 659                          👇👇_PUNCT
# 660     https://t.co/LpepzKdlp1_PROPN
# 661                          RT_PROPN
# 662  @IStandWithTrump47November_PROPN
# 663                          5th_NOUN
# 664                           can_AUX

# %%
import pandas as pd
sta = pd.read_csv("testkorpus_divers_50_stanza.csv")
display(sta[200:215])
# Out:
#      post_id        date                                               text  \
# 200       11  2017-07-21  ICYMI- This week we hosted a #MadeInAmerica ev...
# 201       11  2017-07-21  ICYMI- This week we hosted a #MadeInAmerica ev...
# 202       11  2017-07-21  ICYMI- This week we hosted a #MadeInAmerica ev...
# 203       11  2017-07-21  ICYMI- This week we hosted a #MadeInAmerica ev...
# 204       11  2017-07-21  ICYMI- This week we hosted a #MadeInAmerica ev...
# 205       11  2017-07-21  ICYMI- This week we hosted a #MadeInAmerica ev...
# 206       11  2017-07-21  ICYMI- This week we hosted a #MadeInAmerica ev...
# 207       11  2017-07-21  ICYMI- This week we hosted a #MadeInAmerica ev...
# 208       11  2017-07-21  ICYMI- This week we hosted a #MadeInAmerica ev...
# 209       12  2011-08-31  https://www.mediaite.com/tv/trump-team-scored-...
# 210       13  2018-10-03  Thank you Governor Phil Bryant - it was my gre...
# 211       13  2018-10-03  Thank you Governor Phil Bryant - it was my gre...
# 212       13  2018-10-03  Thank you Governor Phil Bryant - it was my gre...
# 213       13  2018-10-03  Thank you Governor Phil Bryant - it was my gre...
# 214       13  2018-10-03  Thank you Governor Phil Bryant - it was my gre...
#
#                                                   word  \
# 200                                                 it
# 201                                                 is
# 202                                                the
# 203                                               BEST
# 204                                                  !
# 205                                                USA
# 206                                                  🇺
# 207                                                  🇸
# 208                            https://t.co/q4vB9GdE5y
# 209  https://www.mediaite.com/tv/trump-team-scored-...
# 210                                              Thank
# 211                                                you
# 212                                           Governor
# 213                                               Phil
# 214                                             Bryant
#
#                                                  lemma    pos  \
# 200                                                 it   PRON
# 201                                                 be    AUX
# 202                                                the    DET
# 203                                               good    ADJ
# 204                                                  !  PUNCT
# 205                                                USA  PROPN
# 206                                                  🇺  PUNCT
# 207                                                  🇸  PUNCT
# 208                            https://t.co/q4vB9GdE5y  PROPN
# 209  https://www.mediaite.com/tv/trump-team-scored-...  PROPN
# 210                                              thank   VERB
# 211                                                you   PRON
# 212                                           Governor  PROPN
# 213                                               Phil  PROPN
# 214                                             Bryant  PROPN
#
#                                                lemma_p
# 200                                            it_PRON
# 201                                             be_AUX
# 202                                            the_DET
# 203                                           good_ADJ
# 204                                            !_PUNCT
# 205                                          USA_PROPN
# 206                                            🇺_PUNCT
# 207                                            🇸_PUNCT
# 208                      https://t.co/q4vB9GdE5y_PROPN
# 209  https://www.mediaite.com/tv/trump-team-scored-...
# 210                                         thank_VERB
# 211                                           you_PRON
# 212                                     Governor_PROPN
# 213                                         Phil_PROPN
# 214                                       Bryant_PROPN

# %%
sta.shape
# Out:
# (1190, 7)

# %%
#### Stanza + Tweebank ####
import pandas as pd
import stanza
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

stanza.download('en')
stanza_nlp = stanza.Pipeline(
    lang='en',
    processors='tokenize,pos,lemma',
    use_gpu=False
)

# Tweebank
model_name = "TweebankNLP/bertweet-tb2_ewt-pos-tagging"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)

tweebank_tagger = pipeline(
    "token-classification",
    model=model,
    tokenizer=tokenizer,
    aggregation_strategy="simple",
    device=-1  # CPU
)

df = pd.read_csv("testkorpus_divers_50.csv")
df["text"] = df["text"].fillna("").astype(str)

all_results = []
for idx, row in df.iterrows():
    text = row["text"].strip()
    if not text:
        continue

    # Stanza-Analyse (Lemma + Universal POS)
    stanza_doc = stanza_nlp(text)
    stanza_tokens = []
    for sentence in stanza_doc.sentences:
        for token in sentence.tokens:
            word = token.text
            word_info = token.words[0]
            stanza_tokens.append({
                "word": word,
                "lemma": word_info.lemma,
                "upos": word_info.upos
            })

    # Tweebank-Analyse (Tweet-POS-Tags)
    tweebank_result = tweebank_tagger(text)
    tweebank_tokens = [tok.get("word") for tok in tweebank_result]
    tweebank_pos = [tok.get("entity_group") for tok in tweebank_result]

    # Token-Alignierung
    # gleiche Reihenfolge matchen
    min_len = min(len(stanza_tokens), len(tweebank_tokens))
    for i in range(min_len):
        word = stanza_tokens[i]["word"]
        lemma = stanza_tokens[i]["lemma"]
        upos = stanza_tokens[i]["upos"]
        tweet_pos = tweebank_pos[i]

        all_results.append({
            "post_id": idx + 1,
            "date": row.get("date"),
            "word": word,
            "lemma": lemma,
            "upos": upos,          # Universal POS (Stanza)
            "tweebank_pos": tweet_pos,  # Tweet-spezifisches POS
            "lemma_p": f"{lemma}_{upos}"
        })

stat = pd.DataFrame(all_results)
output_file = "testkorpus_divers_50_stanza_tweebank.csv"
stat.to_csv(output_file, index=False, encoding="utf-8")
display(stat.head(30))
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-09-13 14:02:31 INFO: Downloaded file to /Users/vivien/stanza_resources/resources.json
# 2025-09-13 14:02:31 INFO: Downloading default packages for language: en (English) ...
# 2025-09-13 14:02:34 INFO: File exists: /Users/vivien/stanza_resources/en/default.zip
# 2025-09-13 14:02:39 INFO: Finished downloading models and saved to /Users/vivien/stanza_resources
# 2025-09-13 14:02:39 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-09-13 14:07:39 INFO: Downloaded file to /Users/vivien/stanza_resources/resources.json
# 2025-09-13 14:07:39 WARNING: Language en package default expects mwt, which has been added
# 2025-09-13 14:07:40 INFO: Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# =================================
#
# 2025-09-13 14:07:40 INFO: Using device: cpu
# 2025-09-13 14:07:40 INFO: Loading: tokenize
# 2025-09-13 14:07:40 INFO: Loading: mwt
# 2025-09-13 14:07:40 INFO: Loading: pos
# 2025-09-13 14:07:42 INFO: Loading: lemma
# 2025-09-13 14:07:43 INFO: Done loading processors!
# Device set to use cpu
#     post_id        date             word            lemma   upos tweebank_pos  \
# 0         1  2010-11-04         Reminder         reminder   NOUN         NOUN
# 1         1  2010-11-04                :                :  PUNCT        PUNCT
# 2         1  2010-11-04              The              the    DET          DET
# 3         1  2010-11-04             Miss             Miss  PROPN        PROPN
# 4         1  2010-11-04         Universe         Universe  PROPN         NOUN
# 5         1  2010-11-04      competition      competition   NOUN          AUX
# 6         1  2010-11-04             will             will    AUX          ADJ
# 7         1  2010-11-04               be               be    AUX          ADP
# 8         1  2010-11-04             LIVE             live    ADJ          DET
# 9         1  2010-11-04             from             from    ADP        PROPN
# 10        1  2010-11-04              the              the    DET        PUNCT
# 11        1  2010-11-04          Bahamas          Bahamas  PROPN         NOUN
# 12        1  2010-11-04                -                -  PUNCT          ADP
# 13        1  2010-11-04          Tonight          tonight   NOUN          NUM
# 14        1  2010-11-04                @                @    ADP          SYM
# 15        1  2010-11-04                9                9    NUM        PROPN
# 16        1  2010-11-04               pm             p.m.   NOUN        PUNCT
# 17        1  2010-11-04                (                (  PUNCT          ADP
# 18        1  2010-11-04              EST              EST  PROPN        PROPN
# 19        1  2010-11-04                )                )  PUNCT        PUNCT
# 20        1  2010-11-04               on               on    ADP            X
# 21        2  2013-08-15                @                @  PUNCT        PROPN
# 22        2  2013-08-15         Timc1021         Timc1021  PROPN            X
# 23        2  2013-08-15           Thanks           thanks   NOUN         NOUN
# 24        2  2013-08-15                !                !  PUNCT          ADV
# 25        3  2013-06-12                "                "  PUNCT        PUNCT
# 26        3  2013-06-12                "                "  PUNCT            X
# 27        3  2013-06-12  @_KatherineWebb  @_KatherineWebb  PROPN        PUNCT
# 28        3  2013-06-12                :                :  PUNCT         VERB
# 29        3  2013-06-12          Looking             look   VERB          ADV
#
#                   lemma_p
# 0           reminder_NOUN
# 1                 :_PUNCT
# 2                 the_DET
# 3              Miss_PROPN
# 4          Universe_PROPN
# 5        competition_NOUN
# 6                will_AUX
# 7                  be_AUX
# 8                live_ADJ
# 9                from_ADP
# 10                the_DET
# 11          Bahamas_PROPN
# 12                -_PUNCT
# 13           tonight_NOUN
# 14                  @_ADP
# 15                  9_NUM
# 16              p.m._NOUN
# 17                (_PUNCT
# 18              EST_PROPN
# 19                )_PUNCT
# 20                 on_ADP
# 21                @_PUNCT
# 22         Timc1021_PROPN
# 23            thanks_NOUN
# 24                !_PUNCT
# 25                "_PUNCT
# 26                "_PUNCT
# 27  @_KatherineWebb_PROPN
# 28                :_PUNCT
# 29              look_VERB

# %%
import pandas as pd
stat = pd.read_csv("testkorpus_divers_50_stanza_tweebank.csv")
display(stat[:60])
# Out:
#     post_id        date             word            lemma   upos tweebank_pos  \
# 0         1  2010-11-04         Reminder         reminder   NOUN         NOUN
# 1         1  2010-11-04                :                :  PUNCT        PUNCT
# 2         1  2010-11-04              The              the    DET          DET
# 3         1  2010-11-04             Miss             Miss  PROPN        PROPN
# 4         1  2010-11-04         Universe         Universe  PROPN         NOUN
# 5         1  2010-11-04      competition      competition   NOUN          AUX
# 6         1  2010-11-04             will             will    AUX          ADJ
# 7         1  2010-11-04               be               be    AUX          ADP
# 8         1  2010-11-04             LIVE             live    ADJ          DET
# 9         1  2010-11-04             from             from    ADP        PROPN
# 10        1  2010-11-04              the              the    DET        PUNCT
# 11        1  2010-11-04          Bahamas          Bahamas  PROPN         NOUN
# 12        1  2010-11-04                -                -  PUNCT          ADP
# 13        1  2010-11-04          Tonight          tonight   NOUN          NUM
# 14        1  2010-11-04                @                @    ADP          SYM
# 15        1  2010-11-04                9                9    NUM        PROPN
# 16        1  2010-11-04               pm             p.m.   NOUN        PUNCT
# 17        1  2010-11-04                (                (  PUNCT          ADP
# 18        1  2010-11-04              EST              EST  PROPN        PROPN
# 19        1  2010-11-04                )                )  PUNCT        PUNCT
# 20        1  2010-11-04               on               on    ADP            X
# 21        2  2013-08-15                @                @  PUNCT        PROPN
# 22        2  2013-08-15         Timc1021         Timc1021  PROPN            X
# 23        2  2013-08-15           Thanks           thanks   NOUN         NOUN
# 24        2  2013-08-15                !                !  PUNCT          ADV
# 25        3  2013-06-12                "                "  PUNCT        PUNCT
# 26        3  2013-06-12                "                "  PUNCT            X
# 27        3  2013-06-12  @_KatherineWebb  @_KatherineWebb  PROPN        PUNCT
# 28        3  2013-06-12                :                :  PUNCT         VERB
# 29        3  2013-06-12          Looking             look   VERB          ADV
# 30        3  2013-06-12          forward          forward    ADV          ADP
# 31        3  2013-06-12               to               to    ADP        PROPN
# 32        3  2013-06-12                #                #    SYM          DET
# 33        3  2013-06-12          MissUSA          MissUSA  PROPN         NOUN
# 34        3  2013-06-12             this             this    DET          ADP
# 35        3  2013-06-12          weekend          weekend   NOUN        PROPN
# 36        3  2013-06-12               in               in    ADP        PUNCT
# 37        3  2013-06-12            Vegas            Vegas  PROPN          ADJ
# 38        3  2013-06-12                !                !  PUNCT         PART
# 39        3  2013-06-12                "                "  PUNCT         VERB
# 40        3  2013-06-12                "                "  PUNCT         PRON
# 41        3  2013-06-12            Great            great    ADJ         NOUN
# 42        3  2013-06-12               to               to   PART        PUNCT
# 43        3  2013-06-12             have             have   VERB        PROPN
# 44        3  2013-06-12              our              our   PRON        PUNCT
# 45        4  2011-09-04       Addressing          address   VERB         VERB
# 46        4  2011-09-04              the              the    DET          DET
# 47        4  2011-09-04             Rise             rise  PROPN         NOUN
# 48        4  2011-09-04               of               of    ADP          ADP
# 49        4  2011-09-04          Chronic          Chronic    ADJ          ADJ
# 50        4  2011-09-04        Childhood        Childhood  PROPN         NOUN
# 51        4  2011-09-04        Illnesses        Illnesses  PROPN        PUNCT
# 52        4  2011-09-04                .                .  PUNCT            X
# 53        5  2020-05-11               RT               RT  PROPN            X
# 54        5  2020-05-11       @darhar981       @darhar981  PROPN        PUNCT
# 55        5  2020-05-11                :                :  PUNCT        PROPN
# 56        5  2020-05-11         Attorney         Attorney  PROPN          ADJ
# 57        5  2020-05-11          General          General  PROPN        PROPN
# 58        5  2020-05-11           Barr’s             Barr  PROPN         PART
# 59        5  2020-05-11           Office           Office  PROPN        PROPN
#
#                   lemma_p
# 0           reminder_NOUN
# 1                 :_PUNCT
# 2                 the_DET
# 3              Miss_PROPN
# 4          Universe_PROPN
# 5        competition_NOUN
# 6                will_AUX
# 7                  be_AUX
# 8                live_ADJ
# 9                from_ADP
# 10                the_DET
# 11          Bahamas_PROPN
# 12                -_PUNCT
# 13           tonight_NOUN
# 14                  @_ADP
# 15                  9_NUM
# 16              p.m._NOUN
# 17                (_PUNCT
# 18              EST_PROPN
# 19                )_PUNCT
# 20                 on_ADP
# 21                @_PUNCT
# 22         Timc1021_PROPN
# 23            thanks_NOUN
# 24                !_PUNCT
# 25                "_PUNCT
# 26                "_PUNCT
# 27  @_KatherineWebb_PROPN
# 28                :_PUNCT
# 29              look_VERB
# 30            forward_ADV
# 31                 to_ADP
# 32                  #_SYM
# 33          MissUSA_PROPN
# 34               this_DET
# 35           weekend_NOUN
# 36                 in_ADP
# 37            Vegas_PROPN
# 38                !_PUNCT
# 39                "_PUNCT
# 40                "_PUNCT
# 41              great_ADJ
# 42                to_PART
# 43              have_VERB
# 44               our_PRON
# 45           address_VERB
# 46                the_DET
# 47             rise_PROPN
# 48                 of_ADP
# 49            Chronic_ADJ
# 50        Childhood_PROPN
# 51        Illnesses_PROPN
# 52                ._PUNCT
# 53               RT_PROPN
# 54       @darhar981_PROPN
# 55                :_PUNCT
# 56         Attorney_PROPN
# 57          General_PROPN
# 58             Barr_PROPN
# 59           Office_PROPN

# %%
stat.shape
# Out:
# (1081, 7)

# %%
# kurzer Test
import stanza

stanza.download("en")  
nlp = stanza.Pipeline(
    lang="en", 
    processors="tokenize,pos,lemma", 
    tokenize_pretokenized=False,
    use_gpu=False, 
    tokenize_with_spacy=False, 
    tokenize_no_ssplit=False,
    tokenize_engine="tokenize/tweet"
)

# Beispieltext
text = "Donald Trump posted a new tweet. #realdonaldtrump @realdonaldtrump! @ben4appel 🤣 :) https://t.co/bsB6rVV7Yn #Canada"

doc = nlp(text)

for sentence in doc.sentences:
    for word in sentence.words:
        print(word.text, word.lemma, word.upos, word.xpos)
# Hashes werden zu 50% getrennt und zu 50% ganz gelassen.
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-09-13 14:15:07 INFO: Downloaded file to /Users/vivien/stanza_resources/resources.json
# 2025-09-13 14:15:07 INFO: Downloading default packages for language: en (English) ...
# 2025-09-13 14:15:10 INFO: File exists: /Users/vivien/stanza_resources/en/default.zip
# 2025-09-13 14:15:14 INFO: Finished downloading models and saved to /Users/vivien/stanza_resources
# 2025-09-13 14:15:14 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-09-13 14:20:15 INFO: Downloaded file to /Users/vivien/stanza_resources/resources.json
# 2025-09-13 14:20:16 WARNING: Language en package default expects mwt, which has been added
# 2025-09-13 14:20:16 INFO: Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# =================================
#
# 2025-09-13 14:20:16 INFO: Using device: cpu
# 2025-09-13 14:20:16 INFO: Loading: tokenize
# 2025-09-13 14:20:16 INFO: Loading: mwt
# 2025-09-13 14:20:16 INFO: Loading: pos
# 2025-09-13 14:20:19 INFO: Loading: lemma
# 2025-09-13 14:20:20 INFO: Done loading processors!
# Donald Donald PROPN NNP
# Trump Trump PROPN NNP
# posted post VERB VBD
# a a DET DT
# new new ADJ JJ
# tweet tweet NOUN NN
# . . PUNCT .
# #realdonaldtrump #realdonaldtrump PROPN NNP
# @realdonaldtrump @realdonaldtrump PROPN NNP
# ! ! PUNCT .
# @ben4appel @ben4appel PROPN ADD
# 🤣 🤣 PUNCT .
# :) :) SYM NFP
# https://t.co/bsB6rVV7Yn https://t.co/bsB6rVV7Yn PROPN ADD
# # # SYM NN
# Canada Canada PROPN NNP

# %%
## mit Twitter-Tokenizer
import pandas as pd
import stanza
import emoji

stanza.download("en")

# Stanza-Pipeline mit Tweet-Tokenizer
nlp = stanza.Pipeline(
    lang="en",
    processors="tokenize,pos,lemma",
    tokenize_pretokenized=False,
    use_gpu=False,
    tokenize_with_spacy=False,
    tokenize_no_ssplit=False,
    tokenize_engine="tokenize/tweet"
)

df = pd.read_csv("testkorpus_divers_50.csv")

all_results = []

for idx, row in df.iterrows():
    text = row.get("text")
    if pd.isna(text) or not isinstance(text, str) or text.strip() == "":
        continue

    doc = nlp(text)
    for sentence in doc.sentences:
        for word in sentence.words:
            lemma_p = f"{word.lemma}_{word.upos}"
            all_results.append({
                "post_id": idx + 1,
                "date": row.get("date"),
                "word": word.text,
                "lemma": word.lemma,
                "pos": word.upos,   
                "xpos": word.xpos,
                "lemma_p": lemma_p,
            })

statw = pd.DataFrame(all_results)
output_file = "testkorpus_divers_50_stanza_tweets.csv"
statw.to_csv(output_file, index=False, encoding="utf-8")
display(statw.head(20))
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-09-13 14:25:21 INFO: Downloaded file to /Users/vivien/stanza_resources/resources.json
# 2025-09-13 14:25:21 INFO: Downloading default packages for language: en (English) ...
# 2025-09-13 14:25:25 INFO: File exists: /Users/vivien/stanza_resources/en/default.zip
# 2025-09-13 14:25:31 INFO: Finished downloading models and saved to /Users/vivien/stanza_resources
# 2025-09-13 14:25:31 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-09-13 14:30:31 INFO: Downloaded file to /Users/vivien/stanza_resources/resources.json
# 2025-09-13 14:30:32 WARNING: Language en package default expects mwt, which has been added
# 2025-09-13 14:30:32 INFO: Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# =================================
#
# 2025-09-13 14:30:32 INFO: Using device: cpu
# 2025-09-13 14:30:32 INFO: Loading: tokenize
# 2025-09-13 14:30:33 INFO: Loading: mwt
# 2025-09-13 14:30:33 INFO: Loading: pos
# 2025-09-13 14:30:35 INFO: Loading: lemma
# 2025-09-13 14:30:38 INFO: Done loading processors!
#     post_id        date         word        lemma    pos   xpos  \
# 0         1  2010-11-04     Reminder     reminder   NOUN     NN
# 1         1  2010-11-04            :            :  PUNCT      :
# 2         1  2010-11-04          The          the    DET     DT
# 3         1  2010-11-04         Miss         Miss  PROPN    NNP
# 4         1  2010-11-04     Universe     Universe  PROPN    NNP
# 5         1  2010-11-04  competition  competition   NOUN     NN
# 6         1  2010-11-04         will         will    AUX     MD
# 7         1  2010-11-04           be           be    AUX     VB
# 8         1  2010-11-04         LIVE         live    ADJ     JJ
# 9         1  2010-11-04         from         from    ADP     IN
# 10        1  2010-11-04          the          the    DET     DT
# 11        1  2010-11-04      Bahamas      Bahamas  PROPN    NNP
# 12        1  2010-11-04            -            -  PUNCT      ,
# 13        1  2010-11-04      Tonight      tonight   NOUN     NN
# 14        1  2010-11-04            @            @    ADP     IN
# 15        1  2010-11-04            9            9    NUM     CD
# 16        1  2010-11-04           pm         p.m.   NOUN     NN
# 17        1  2010-11-04            (            (  PUNCT  -LRB-
# 18        1  2010-11-04          EST          EST  PROPN    NNP
# 19        1  2010-11-04            )            )  PUNCT  -RRB-
#
#              lemma_p
# 0      reminder_NOUN
# 1            :_PUNCT
# 2            the_DET
# 3         Miss_PROPN
# 4     Universe_PROPN
# 5   competition_NOUN
# 6           will_AUX
# 7             be_AUX
# 8           live_ADJ
# 9           from_ADP
# 10           the_DET
# 11     Bahamas_PROPN
# 12           -_PUNCT
# 13      tonight_NOUN
# 14             @_ADP
# 15             9_NUM
# 16         p.m._NOUN
# 17           (_PUNCT
# 18         EST_PROPN
# 19           )_PUNCT

# %%
import pandas as pd
statw = pd.read_csv("testkorpus_divers_50_stanza_tweets.csv")
display(statw[200:215])
# Out:
#      post_id        date                                               word  \
# 200       11  2017-07-21                                               MADE
# 201       11  2017-07-21                                                 IN
# 202       11  2017-07-21                                            AMERICA
# 203       11  2017-07-21                                                  ,
# 204       11  2017-07-21                                                 it
# 205       11  2017-07-21                                                 is
# 206       11  2017-07-21                                                the
# 207       11  2017-07-21                                               BEST
# 208       11  2017-07-21                                                  !
# 209       11  2017-07-21                                                USA
# 210       11  2017-07-21                                                  🇺
# 211       11  2017-07-21                                                  🇸
# 212       11  2017-07-21                            https://t.co/q4vB9GdE5y
# 213       12  2011-08-31  https://www.mediaite.com/tv/trump-team-scored-...
# 214       13  2018-10-03                                              Thank
#
#                                                  lemma    pos xpos  \
# 200                                               made   VERB  VBN
# 201                                                 in    ADP   IN
# 202                                            America  PROPN  NNP
# 203                                                  ,  PUNCT    ,
# 204                                                 it   PRON  PRP
# 205                                                 be    AUX  VBZ
# 206                                                the    DET   DT
# 207                                               good    ADJ  JJS
# 208                                                  !  PUNCT    .
# 209                                                USA  PROPN  NNP
# 210                                                  🇺  PUNCT    ,
# 211                                                  🇸  PUNCT    .
# 212                            https://t.co/q4vB9GdE5y  PROPN  ADD
# 213  https://www.mediaite.com/tv/trump-team-scored-...  PROPN  ADD
# 214                                              thank   VERB  VBP
#
#                                                lemma_p
# 200                                          made_VERB
# 201                                             in_ADP
# 202                                      America_PROPN
# 203                                            ,_PUNCT
# 204                                            it_PRON
# 205                                             be_AUX
# 206                                            the_DET
# 207                                           good_ADJ
# 208                                            !_PUNCT
# 209                                          USA_PROPN
# 210                                            🇺_PUNCT
# 211                                            🇸_PUNCT
# 212                      https://t.co/q4vB9GdE5y_PROPN
# 213  https://www.mediaite.com/tv/trump-team-scored-...
# 214                                         thank_VERB

# %%
statw.shape
# taggt sehr gut, allerdings wird nicht jedes Emoji richtig als NFP erkannt, 
# sondern oft nur als Satzzeichen.
# Out:
# (1207, 7)

# %%
# Stanza + Tweet-Tokenizer + Emojivariante
import pandas as pd
import stanza
import re

stanza.download("en")

# Stanza-Pipeline mit Tweet-Tokenizer
nlp = stanza.Pipeline(
    lang="en",
    processors="tokenize,pos,lemma",
    tokenize_pretokenized=False,
    use_gpu=False,
    tokenize_with_spacy=False,
    tokenize_no_ssplit=False,
    tokenize_engine="tokenize/tweet"
)


# Unicode-Emoji-Regex
emoji_pattern = re.compile("["
    u"\U0001F600-\U0001F64F"  # Emoticons
    u"\U0001F300-\U0001F5FF"  # Symbole & Piktogramme
    u"\U0001F680-\U0001F6FF"  # Transport & Symbole
    u"\U0001F1E0-\U0001F1FF"  # Flaggen
    "]+", flags=re.UNICODE)

# klassische Smileys
smiley_pattern = re.compile(r'[:;=8][\-~]?[)D]', flags=re.UNICODE)

def is_emoji_or_smiley(token):
    return bool(emoji_pattern.fullmatch(token)) or bool(smiley_pattern.fullmatch(token))


df = pd.read_csv("testkorpus_divers_50.csv")
all_results = []

for idx, row in df.iterrows():
    text = row.get("text")
    if pd.isna(text) or not isinstance(text, str) or text.strip() == "":
        continue

    doc = nlp(text)
    for sentence in doc.sentences:
        for word in sentence.words:
            xpos = word.xpos
            if is_emoji_or_smiley(word.text):
                xpos = "NFP"

            lemma_p = f"{word.lemma}_{word.upos}"
            all_results.append({
                "post_id": idx + 1,
                "date": row.get("date"),
                "word": word.text,
                "lemma": word.lemma,
                "pos": word.upos,   
                "xpos": xpos,
                "lemma_p": lemma_p,
            })

statw2 = pd.DataFrame(all_results)
output_file = "testkorpus_divers_50_stanza_tweets2.csv"
statw2.to_csv(output_file, index=False, encoding="utf-8")
display(statw2.head(20))
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-09-13 14:36:34 INFO: Downloaded file to /Users/vivien/stanza_resources/resources.json
# 2025-09-13 14:36:34 INFO: Downloading default packages for language: en (English) ...
# 2025-09-13 14:36:37 INFO: File exists: /Users/vivien/stanza_resources/en/default.zip
# 2025-09-13 14:36:42 INFO: Finished downloading models and saved to /Users/vivien/stanza_resources
# 2025-09-13 14:36:42 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-09-13 14:41:42 INFO: Downloaded file to /Users/vivien/stanza_resources/resources.json
# 2025-09-13 14:41:42 WARNING: Language en package default expects mwt, which has been added
# 2025-09-13 14:41:43 INFO: Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# =================================
#
# 2025-09-13 14:41:43 INFO: Using device: cpu
# 2025-09-13 14:41:43 INFO: Loading: tokenize
# 2025-09-13 14:41:43 INFO: Loading: mwt
# 2025-09-13 14:41:43 INFO: Loading: pos
# 2025-09-13 14:41:46 INFO: Loading: lemma
# 2025-09-13 14:41:47 INFO: Done loading processors!
#     post_id        date         word        lemma    pos   xpos  \
# 0         1  2010-11-04     Reminder     reminder   NOUN     NN
# 1         1  2010-11-04            :            :  PUNCT      :
# 2         1  2010-11-04          The          the    DET     DT
# 3         1  2010-11-04         Miss         Miss  PROPN    NNP
# 4         1  2010-11-04     Universe     Universe  PROPN    NNP
# 5         1  2010-11-04  competition  competition   NOUN     NN
# 6         1  2010-11-04         will         will    AUX     MD
# 7         1  2010-11-04           be           be    AUX     VB
# 8         1  2010-11-04         LIVE         live    ADJ     JJ
# 9         1  2010-11-04         from         from    ADP     IN
# 10        1  2010-11-04          the          the    DET     DT
# 11        1  2010-11-04      Bahamas      Bahamas  PROPN    NNP
# 12        1  2010-11-04            -            -  PUNCT      ,
# 13        1  2010-11-04      Tonight      tonight   NOUN     NN
# 14        1  2010-11-04            @            @    ADP     IN
# 15        1  2010-11-04            9            9    NUM     CD
# 16        1  2010-11-04           pm         p.m.   NOUN     NN
# 17        1  2010-11-04            (            (  PUNCT  -LRB-
# 18        1  2010-11-04          EST          EST  PROPN    NNP
# 19        1  2010-11-04            )            )  PUNCT  -RRB-
#
#              lemma_p
# 0      reminder_NOUN
# 1            :_PUNCT
# 2            the_DET
# 3         Miss_PROPN
# 4     Universe_PROPN
# 5   competition_NOUN
# 6           will_AUX
# 7             be_AUX
# 8           live_ADJ
# 9           from_ADP
# 10           the_DET
# 11     Bahamas_PROPN
# 12           -_PUNCT
# 13      tonight_NOUN
# 14             @_ADP
# 15             9_NUM
# 16         p.m._NOUN
# 17           (_PUNCT
# 18         EST_PROPN
# 19           )_PUNCT

# %%
import pandas as pd
statw2 = pd.read_csv("testkorpus_divers_50_stanza_tweets2.csv")
display(statw2[200:215])
# Out:
#      post_id        date                                               word  \
# 200       11  2017-07-21                                               MADE
# 201       11  2017-07-21                                                 IN
# 202       11  2017-07-21                                            AMERICA
# 203       11  2017-07-21                                                  ,
# 204       11  2017-07-21                                                 it
# 205       11  2017-07-21                                                 is
# 206       11  2017-07-21                                                the
# 207       11  2017-07-21                                               BEST
# 208       11  2017-07-21                                                  !
# 209       11  2017-07-21                                                USA
# 210       11  2017-07-21                                                  🇺
# 211       11  2017-07-21                                                  🇸
# 212       11  2017-07-21                            https://t.co/q4vB9GdE5y
# 213       12  2011-08-31  https://www.mediaite.com/tv/trump-team-scored-...
# 214       13  2018-10-03                                              Thank
#
#                                                  lemma    pos xpos  \
# 200                                               made   VERB  VBN
# 201                                                 in    ADP   IN
# 202                                            America  PROPN  NNP
# 203                                                  ,  PUNCT    ,
# 204                                                 it   PRON  PRP
# 205                                                 be    AUX  VBZ
# 206                                                the    DET   DT
# 207                                               good    ADJ  JJS
# 208                                                  !  PUNCT    .
# 209                                                USA  PROPN  NNP
# 210                                                  🇺  PUNCT  NFP
# 211                                                  🇸  PUNCT  NFP
# 212                            https://t.co/q4vB9GdE5y  PROPN  ADD
# 213  https://www.mediaite.com/tv/trump-team-scored-...  PROPN  ADD
# 214                                              thank   VERB  VBP
#
#                                                lemma_p
# 200                                          made_VERB
# 201                                             in_ADP
# 202                                      America_PROPN
# 203                                            ,_PUNCT
# 204                                            it_PRON
# 205                                             be_AUX
# 206                                            the_DET
# 207                                           good_ADJ
# 208                                            !_PUNCT
# 209                                          USA_PROPN
# 210                                            🇺_PUNCT
# 211                                            🇸_PUNCT
# 212                      https://t.co/q4vB9GdE5y_PROPN
# 213  https://www.mediaite.com/tv/trump-team-scored-...
# 214                                         thank_VERB

# %%
statw2.shape
# Out:
# (1207, 7)

# %% [markdown]
# Fazit zu Stanza:
# - weniger Tags als alle anderen Modelle
# - @ werden meistens gut erkannt (und so belassen wie sie waren)
# - Emojis werden als Punkt erkannt
# - Hashes werden meist getrennt
# - Links als Eigenname, aber werden ganz gelassen
# - richtige Lemmatisierung
# - meistens richtiges Tagging
# - Barr's wird zu Barr als PROPN - Tweebank trennt in Barr 's auf
# - Shreds und its (Rechtschreibfehler) falsch erkannt, ol' als Noun (eigentl. old, Tweebank hatte ol' als ADJ)
# - doesn't wird zu do (lemma)
# - in Kombination mit Tweebank: leider sehr schlechtes Tokenisieren (zu viele X)
# ##### mit Tweet-Tokenizer:
# - super
# - am besten xpos verwenden, da diese Tweet-spezifische Tags beinhalten
# - Hashes und @ werden gut erkannt und entsprechend getaggt
# - Links bei xpos mit ADD getagt, bei pos (also nicht tweetspezifisch) mit PROPN
# - Emojis werden meist als Satzzeichen getaggt und nur selten als NFP
# - Barr's wird aufgeteilt in Barr und 's
# - Hashes und @ werden allerdings auch genau so oft getrennt, wie sie zusammen gelassen werden
# - zwei neue Tags für Tweets: ADD und NFP
# ##### Tweet Tokenizer 2:
# - Emojis werden besser erkannt als NFP
# - der Rest ist identisch mit dem ersten Tweet-Tokenizer Modell

# %% [raw]
# XPOS	Beschreibung	Beispiele / Typische Tokens
# NNP	Proper Noun, Singular	Donald, Canada, #Canada
# NN	Noun, Singular	# (Hashtag-Symbol)
# ADD	Addresse / Mention / URL	@ben4appel, @realdonaldtrump, https://t.co/...
# NFP	Non-final punctuation / Emoticons	:) , 🤣
# DT	Determiner	a, the
# JJ	Adjective	new, happy
# VB	Verb, base form	post, like
# VBD	Verb, past tense	posted
# PUNCT	Satzzeichen	., !, ?
# SYM	Symbol	#, $, %, &
# PRP$	Possessive pronoun	my, your
# RB	Adverb	quickly, now

# %% [markdown]
# # Flair
# - https://huggingface.co/flair/pos-english: F1 Score: 98,18
# - https://huggingface.co/flair/pos-english-fast: 98,10
# - https://huggingface.co/flair/upos-english: 98,6
# - https://huggingface.co/flair/upos-english-fast: 98,47

# %%
# !pip install flair # bei Modell pos oder upos wählbar

# %%
#### Flair mit UPOS ####
import logging
import pandas as pd
from flair.data import Sentence
from flair.models import SequenceTagger

logging.getLogger("flair").setLevel(logging.ERROR)
df = pd.read_csv("testkorpus_divers_50.csv")
df_nonempty = df[df["text"].notna()].copy()
tagger = SequenceTagger.load("flair/upos-english")
label_type = tagger.label_type

sentences = [Sentence(str(t)) for t in df_nonempty["text"]]
tagger.predict(sentences, mini_batch_size=32)

all_results = []
for row, sentence in zip(df_nonempty.itertuples(index=True), sentences):
    for token in sentence:
        # POS-Label 
        pos_label = token.get_label(label_type).value if token.has_label(label_type) else None

        all_results.append({
            "post_id": row.Index,
            "date": getattr(row, "date", None),
            "word": token.text,
            "lemma": token.text.lower(),           # Flair liefert kein Lemma
            "pos": pos_label,
            "lemma_p": f"{token.text.lower()}_{pos_label}" if pos_label else token.text.lower()
        })
        
fl = pd.DataFrame(all_results)
fl.to_csv("testkorpus_divers_50_flair.csv", index=False)
display(fl.head(20))
# Out:
#     post_id        date         word        lemma    pos            lemma_p
# 0         0  2010-11-04     Reminder     reminder   INTJ      reminder_INTJ
# 1         0  2010-11-04            :            :  PUNCT            :_PUNCT
# 2         0  2010-11-04          The          the  PROPN          the_PROPN
# 3         0  2010-11-04         Miss         miss  PROPN         miss_PROPN
# 4         0  2010-11-04     Universe     universe  PROPN     universe_PROPN
# 5         0  2010-11-04  competition  competition  PROPN  competition_PROPN
# 6         0  2010-11-04         will         will    AUX           will_AUX
# 7         0  2010-11-04           be           be   VERB            be_VERB
# 8         0  2010-11-04         LIVE         live   VERB          live_VERB
# 9         0  2010-11-04         from         from    ADP           from_ADP
# 10        0  2010-11-04          the          the    SYM            the_SYM
# 11        0  2010-11-04      Bahamas      bahamas    NUM        bahamas_NUM
# 12        0  2010-11-04            -            -  PUNCT            -_PUNCT
# 13        0  2010-11-04      Tonight      tonight   VERB       tonight_VERB
# 14        0  2010-11-04            @            @    SYM              @_SYM
# 15        0  2010-11-04          9pm          9pm    NUM            9pm_NUM
# 16        0  2010-11-04            (            (    SYM              (_SYM
# 17        0  2010-11-04          EST          est    NUM            est_NUM
# 18        0  2010-11-04            )            )      X                )_X
# 19        0  2010-11-04           on           on    SYM             on_SYM

# %%
import pandas as pd
fl = pd.read_csv("testkorpus_divers_50_flair.csv")
display(fl[70:115])
# Out:
#      post_id        date             word            lemma    pos  \
# 70         4  2020-05-11           Shreds           shreds    NUM
# 71         4  2020-05-11              NBC              nbc    SYM
# 72         4  2020-05-11               ’s               ’s    NUM
# 73         4  2020-05-11            Chuck            chuck   NOUN
# 74         4  2020-05-11             Todd             todd    SYM
# 75         4  2020-05-11              For              for    NUM
# 76         4  2020-05-11                ‘                ‘    SYM
# 77         4  2020-05-11        Deceptive        deceptive    NUM
# 78         4  2020-05-11         Editing’         editing’    SYM
# 79         4  2020-05-11               Of               of    NUM
# 80         4  2020-05-11             Barr             barr  PUNCT
# 81         4  2020-05-11               ’s               ’s    SYM
# 82         4  2020-05-11         Comments         comments    NUM
# 83         4  2020-05-11               On               on    SYM
# 84         4  2020-05-11                “                “    NUM
# 85         4  2020-05-11             Meet             meet    SYM
# 86         4  2020-05-11              The              the    NUM
# 87         4  2020-05-11            Press            press   NOUN
# 88         4  2020-05-11               ,”               ,”    SYM
# 89         4  2020-05-11             Todd             todd    NUM
# 90         4  2020-05-11                …                …  PUNCT
# 91         5  2011-09-07               RT               rt      X
# 92         5  2011-09-07                @                @      X
# 93         5  2011-09-07         MagaGlam         magaglam      X
# 94         5  2011-09-07              🇺🇸♥              🇺🇸♥    SYM
# 95         5  2011-09-07            Bring            bring   VERB
# 96         5  2011-09-07             Back             back    SYM
# 97         5  2011-09-07            Trump            trump    NUM
# 98         5  2011-09-07              💙🇺🇸              💙🇺🇸    SYM
# 99         7  2025-03-19              The              the    DET
# 100        7  2025-03-19              CBP              cbp  PROPN
# 101        7  2025-03-19             Home             home  PROPN
# 102        7  2025-03-19              App              app  PROPN
# 103        7  2025-03-19               is               is   VERB
# 104        7  2025-03-19              now              now    ADV
# 105        7  2025-03-19        available        available   VERB
# 106        7  2025-03-19           across           across    ADP
# 107        7  2025-03-19              all              all    NUM
# 108        7  2025-03-19           mobile           mobile  PROPN
# 109        7  2025-03-19              App              app  PROPN
# 110        7  2025-03-19           Stores           stores  PROPN
# 111        7  2025-03-19                !                !  PUNCT
# 112        8  2019-01-23  Congratulations  congratulations   VERB
# 113        8  2019-01-23               to               to  PROPN
# 114        8  2019-01-23          Mariano          mariano  PROPN
#
#                   lemma_p
# 70             shreds_NUM
# 71                nbc_SYM
# 72                 ’s_NUM
# 73             chuck_NOUN
# 74               todd_SYM
# 75                for_NUM
# 76                  ‘_SYM
# 77          deceptive_NUM
# 78           editing’_SYM
# 79                 of_NUM
# 80             barr_PUNCT
# 81                 ’s_SYM
# 82           comments_NUM
# 83                 on_SYM
# 84                  “_NUM
# 85               meet_SYM
# 86                the_NUM
# 87             press_NOUN
# 88                 ,”_SYM
# 89               todd_NUM
# 90                …_PUNCT
# 91                   rt_X
# 92                    @_X
# 93             magaglam_X
# 94                🇺🇸♥_SYM
# 95             bring_VERB
# 96               back_SYM
# 97              trump_NUM
# 98                💙🇺🇸_SYM
# 99                the_DET
# 100             cbp_PROPN
# 101            home_PROPN
# 102             app_PROPN
# 103               is_VERB
# 104               now_ADV
# 105        available_VERB
# 106            across_ADP
# 107               all_NUM
# 108          mobile_PROPN
# 109             app_PROPN
# 110          stores_PROPN
# 111               !_PUNCT
# 112  congratulations_VERB
# 113              to_PROPN
# 114         mariano_PROPN

# %%
fl.shape
# Out:
# (1357, 6)

# %%
#### Flair mit POS ####
import logging
import pandas as pd
from flair.data import Sentence
from flair.models import SequenceTagger

logging.getLogger("flair").setLevel(logging.ERROR)
df = pd.read_csv("testkorpus_divers_50.csv")
df_nonempty = df[df["text"].notna()].copy()
tagger = SequenceTagger.load("flair/pos-english")
label_type = tagger.label_type

sentences = [Sentence(str(t)) for t in df_nonempty["text"]]
tagger.predict(sentences, mini_batch_size=32)

all_results = []
for row, sentence in zip(df_nonempty.itertuples(index=True), sentences):
    for token in sentence:
        # POS-Label 
        pos_label = token.get_label(label_type).value if token.has_label(label_type) else None

        all_results.append({
            "post_id": row.Index,
            "date": getattr(row, "date", None),
            "word": token.text,
            "lemma": token.text.lower(),           # Flair liefert kein Lemma
            "pos": pos_label,
            "lemma_p": f"{token.text.lower()}_{pos_label}" if pos_label else token.text.lower()
        })
        
fl2 = pd.DataFrame(all_results)
fl2.to_csv("testkorpus_divers_50_flair.csv", index=False)
display(fl2.head(20))
# Out:
#     post_id        date         word        lemma    pos         lemma_p
# 0         0  2010-11-04     Reminder     reminder     NN     reminder_NN
# 1         0  2010-11-04            :            :      :             :_:
# 2         0  2010-11-04          The          the     DT          the_DT
# 3         0  2010-11-04         Miss         miss    NNP        miss_NNP
# 4         0  2010-11-04     Universe     universe    NNP    universe_NNP
# 5         0  2010-11-04  competition  competition     NN  competition_NN
# 6         0  2010-11-04         will         will     MD         will_MD
# 7         0  2010-11-04           be           be     VB           be_VB
# 8         0  2010-11-04         LIVE         live     RB         live_RB
# 9         0  2010-11-04         from         from     IN         from_IN
# 10        0  2010-11-04          the          the     DT          the_DT
# 11        0  2010-11-04      Bahamas      bahamas   NNPS    bahamas_NNPS
# 12        0  2010-11-04            -            -      :             -_:
# 13        0  2010-11-04      Tonight      tonight    NNP     tonight_NNP
# 14        0  2010-11-04            @            @     IN            @_IN
# 15        0  2010-11-04          9pm          9pm     NN          9pm_NN
# 16        0  2010-11-04            (            (      :             (_:
# 17        0  2010-11-04          EST          est    NNP         est_NNP
# 18        0  2010-11-04            )            )  -RRB-         )_-RRB-
# 19        0  2010-11-04           on           on     IN           on_IN

# %%
import pandas as pd
fl2 = pd.read_csv("testkorpus_divers_50_flair.csv")
display(fl2[70:115])
# Out:
#      post_id        date             word            lemma   pos  \
# 70         4  2020-05-11           Shreds           shreds   VBZ
# 71         4  2020-05-11              NBC              nbc   NNP
# 72         4  2020-05-11               ’s               ’s   VBZ
# 73         4  2020-05-11            Chuck            chuck   NNP
# 74         4  2020-05-11             Todd             todd   NNP
# 75         4  2020-05-11              For              for    IN
# 76         4  2020-05-11                ‘                ‘    ``
# 77         4  2020-05-11        Deceptive        deceptive    JJ
# 78         4  2020-05-11         Editing’         editing’    NN
# 79         4  2020-05-11               Of               of    IN
# 80         4  2020-05-11             Barr             barr   NNP
# 81         4  2020-05-11               ’s               ’s   VBZ
# 82         4  2020-05-11         Comments         comments   NNS
# 83         4  2020-05-11               On               on    IN
# 84         4  2020-05-11                “                “    ``
# 85         4  2020-05-11             Meet             meet    VB
# 86         4  2020-05-11              The              the    DT
# 87         4  2020-05-11            Press            press    NN
# 88         4  2020-05-11               ,”               ,”     ,
# 89         4  2020-05-11             Todd             todd   NNP
# 90         4  2020-05-11                …                …     .
# 91         5  2011-09-07               RT               rt    NN
# 92         5  2011-09-07                @                @   SYM
# 93         5  2011-09-07         MagaGlam         magaglam   NNP
# 94         5  2011-09-07              🇺🇸♥              🇺🇸♥   NFP
# 95         5  2011-09-07            Bring            bring    VB
# 96         5  2011-09-07             Back             back    RB
# 97         5  2011-09-07            Trump            trump    NN
# 98         5  2011-09-07              💙🇺🇸              💙🇺🇸   NFP
# 99         7  2025-03-19              The              the    DT
# 100        7  2025-03-19              CBP              cbp   NNP
# 101        7  2025-03-19             Home             home   NNP
# 102        7  2025-03-19              App              app   NNP
# 103        7  2025-03-19               is               is   VBZ
# 104        7  2025-03-19              now              now    RB
# 105        7  2025-03-19        available        available    JJ
# 106        7  2025-03-19           across           across    IN
# 107        7  2025-03-19              all              all    DT
# 108        7  2025-03-19           mobile           mobile    JJ
# 109        7  2025-03-19              App              app   NNP
# 110        7  2025-03-19           Stores           stores  NNPS
# 111        7  2025-03-19                !                !     .
# 112        8  2019-01-23  Congratulations  congratulations   NNS
# 113        8  2019-01-23               to               to    IN
# 114        8  2019-01-23          Mariano          mariano   NNP
#
#                  lemma_p
# 70            shreds_VBZ
# 71               nbc_NNP
# 72                ’s_VBZ
# 73             chuck_NNP
# 74              todd_NNP
# 75                for_IN
# 76                  ‘_``
# 77          deceptive_JJ
# 78           editing’_NN
# 79                 of_IN
# 80              barr_NNP
# 81                ’s_VBZ
# 82          comments_NNS
# 83                 on_IN
# 84                  “_``
# 85               meet_VB
# 86                the_DT
# 87              press_NN
# 88                  ,”_,
# 89              todd_NNP
# 90                   …_.
# 91                 rt_NN
# 92                 @_SYM
# 93          magaglam_NNP
# 94               🇺🇸♥_NFP
# 95              bring_VB
# 96               back_RB
# 97              trump_NN
# 98               💙🇺🇸_NFP
# 99                the_DT
# 100              cbp_NNP
# 101             home_NNP
# 102              app_NNP
# 103               is_VBZ
# 104               now_RB
# 105         available_JJ
# 106            across_IN
# 107               all_DT
# 108            mobile_JJ
# 109              app_NNP
# 110          stores_NNPS
# 111                  !_.
# 112  congratulations_NNS
# 113                to_IN
# 114          mariano_NNP

# %%
fl2.shape
# Out:
# (1357, 6)

# %% [markdown]
# Auf den ersten Blick kommt flair mit POS Tagging nicht sehr gut klar, wie SpaCy oder Stanza.

# %%
#### Flair und SpaCy ####
import pandas as pd
from flair.data import Sentence
from flair.models import SequenceTagger
import spacy

df = pd.read_csv("testkorpus_divers_50.csv")
tagger = SequenceTagger.load("pos-fast")
nlp = spacy.load("en_core_web_sm")

all_results = []

for idx, row in df.iterrows():
    text = row['text']
    if pd.isna(text):
        continue

    spacy_doc = nlp(str(text))

    flair_sentence = Sentence(str(text))
    tagger.predict(flair_sentence)

    # Achtung: Flair und SpaCy tokenisieren unterschiedlich!
    if len(flair_sentence) == len(spacy_doc):
        for flair_token, spacy_token in zip(flair_sentence, spacy_doc):
            all_results.append({
                "post_id": idx,
                "date": row.get("date"),
                "word": flair_token.text,
                "lemma": spacy_token.lemma_, #für Lemma Spacy verwenden
                "pos": flair_token.get_label('pos').value,
                "lemma_p": f"{spacy_token.lemma_}_{flair_token.get_label('pos').value}"
            })
    else:
        # Falls Tokenanzahl nicht übereinstimmt
        for flair_token in flair_sentence:
            all_results.append({
                "post_id": idx,
                "date": row.get("date"),
                "word": flair_token.text,
                "lemma": flair_token.text.lower(),
                "pos": flair_token.get_label('pos').value,
                "lemma_p": f"{flair_token.text.lower()}_{flair_token.get_label('pos').value}"
            })

flsp = pd.DataFrame(all_results)
flsp.to_csv("testkorpus_divers_50_flair_spacy.csv", index=False)
display(flsp.head(20))
# Out:
#     post_id        date         word        lemma    pos         lemma_p
# 0         0  2010-11-04     Reminder     reminder     NN     reminder_NN
# 1         0  2010-11-04            :            :      :             :_:
# 2         0  2010-11-04          The          the     DT          the_DT
# 3         0  2010-11-04         Miss         miss    NNP        miss_NNP
# 4         0  2010-11-04     Universe     universe    NNP    universe_NNP
# 5         0  2010-11-04  competition  competition     NN  competition_NN
# 6         0  2010-11-04         will         will     MD         will_MD
# 7         0  2010-11-04           be           be     VB           be_VB
# 8         0  2010-11-04         LIVE         live     JJ         live_JJ
# 9         0  2010-11-04         from         from     IN         from_IN
# 10        0  2010-11-04          the          the     DT          the_DT
# 11        0  2010-11-04      Bahamas      bahamas    NNP     bahamas_NNP
# 12        0  2010-11-04            -            -   HYPH          -_HYPH
# 13        0  2010-11-04      Tonight      tonight    NNP     tonight_NNP
# 14        0  2010-11-04            @            @     CC            @_CC
# 15        0  2010-11-04          9pm          9pm     NN          9pm_NN
# 16        0  2010-11-04            (            (      :             (_:
# 17        0  2010-11-04          EST          est    NNP         est_NNP
# 18        0  2010-11-04            )            )  -RRB-         )_-RRB-
# 19        0  2010-11-04           on           on     IN           on_IN

# %%
import pandas as pd
flsp = pd.read_csv("testkorpus_divers_50_flair_spacy.csv")
display(flsp[70:115])
# Out:
#      post_id        date             word            lemma   pos  \
# 70         4  2020-05-11           Shreds           shreds   VBZ
# 71         4  2020-05-11              NBC              nbc   NNP
# 72         4  2020-05-11               ’s               ’s   VBZ
# 73         4  2020-05-11            Chuck            chuck   NNP
# 74         4  2020-05-11             Todd             todd   NNP
# 75         4  2020-05-11              For              for    IN
# 76         4  2020-05-11                ‘                ‘    ``
# 77         4  2020-05-11        Deceptive        deceptive    JJ
# 78         4  2020-05-11         Editing’         editing’    NN
# 79         4  2020-05-11               Of               of    IN
# 80         4  2020-05-11             Barr             barr   NNP
# 81         4  2020-05-11               ’s               ’s   POS
# 82         4  2020-05-11         Comments         comments   NNS
# 83         4  2020-05-11               On               on    IN
# 84         4  2020-05-11                “                “    ``
# 85         4  2020-05-11             Meet             meet    VB
# 86         4  2020-05-11              The              the    DT
# 87         4  2020-05-11            Press            press    NN
# 88         4  2020-05-11               ,”               ,”   NFP
# 89         4  2020-05-11             Todd             todd   NNP
# 90         4  2020-05-11                …                …     .
# 91         5  2011-09-07               RT               rt   NNP
# 92         5  2011-09-07                @                @    CC
# 93         5  2011-09-07         MagaGlam         magaglam   NNP
# 94         5  2011-09-07              🇺🇸♥              🇺🇸♥   NFP
# 95         5  2011-09-07            Bring            bring    VB
# 96         5  2011-09-07             Back             back    RB
# 97         5  2011-09-07            Trump            trump    NN
# 98         5  2011-09-07              💙🇺🇸              💙🇺🇸   NFP
# 99         7  2025-03-19              The              the    DT
# 100        7  2025-03-19              CBP              CBP   NNP
# 101        7  2025-03-19             Home             Home   NNP
# 102        7  2025-03-19              App              App   NNP
# 103        7  2025-03-19               is               be   VBZ
# 104        7  2025-03-19              now              now    RB
# 105        7  2025-03-19        available        available    JJ
# 106        7  2025-03-19           across           across    IN
# 107        7  2025-03-19              all              all    DT
# 108        7  2025-03-19           mobile           mobile    JJ
# 109        7  2025-03-19              App              App   NNP
# 110        7  2025-03-19           Stores            store  NNPS
# 111        7  2025-03-19                !                !     .
# 112        8  2019-01-23  Congratulations  congratulations   NNS
# 113        8  2019-01-23               to               to    IN
# 114        8  2019-01-23          Mariano          mariano   NNP
#
#                  lemma_p
# 70            shreds_VBZ
# 71               nbc_NNP
# 72                ’s_VBZ
# 73             chuck_NNP
# 74              todd_NNP
# 75                for_IN
# 76                  ‘_``
# 77          deceptive_JJ
# 78           editing’_NN
# 79                 of_IN
# 80              barr_NNP
# 81                ’s_POS
# 82          comments_NNS
# 83                 on_IN
# 84                  “_``
# 85               meet_VB
# 86                the_DT
# 87              press_NN
# 88                ,”_NFP
# 89              todd_NNP
# 90                   …_.
# 91                rt_NNP
# 92                  @_CC
# 93          magaglam_NNP
# 94               🇺🇸♥_NFP
# 95              bring_VB
# 96               back_RB
# 97              trump_NN
# 98               💙🇺🇸_NFP
# 99                the_DT
# 100              CBP_NNP
# 101             Home_NNP
# 102              App_NNP
# 103               be_VBZ
# 104               now_RB
# 105         available_JJ
# 106            across_IN
# 107               all_DT
# 108            mobile_JJ
# 109              App_NNP
# 110           store_NNPS
# 111                  !_.
# 112  congratulations_NNS
# 113                to_IN
# 114          mariano_NNP

# %%
flsp.shape
# Out:
# (1357, 6)

# %% [markdown]
# Fazit zu Flair:
# - Tagging trift oft nicht zu (zu viel NUM und SYM) vor allem bei Namen
# - Zerteilung der Links
# - Trennung der Hashes und @ (immerhin wortweise)
# - Emojis als SYM und gut getrennt
# flair_spacy: anderes Tagset
# - Lemmatisierung nicht ganz richtig (nur lower)
# - Emojis auch gut getrennt, aber als NFP
# flair-spacy2: auch anderes Tagset
# - Lemmatisierung schlechter
# - Tagging ok
# - Emojis auch als NFP, nicht so gut getrennt
# - LL. Bean wird als gemeinsamer Ausdruck erkannt! (Bei Stanza, Bert und Tweebank nicht)
# - ol' richtig als JJ
# - @ als CC
# - Links als eigener Satz getaggt, was es falsch macht und dadurch zu viel aufsplittet

# %% [markdown]
# # Bert
# https://huggingface.co/vblagoje/bert-english-uncased-finetuned-pos

# %%
#### Bert mit SpaCy ####
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForTokenClassification
import spacy

model_name = "vblagoje/bert-english-uncased-finetuned-pos"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)
model.eval()

nlp = spacy.load("en_core_web_sm")
id2label = model.config.id2label

df = pd.read_csv("testkorpus_divers_50.csv")
text_col = "text"

results = []


for idx, row in df.iterrows():
    text = row.get(text_col)
    if pd.isna(text):
        continue

    spacy_doc = nlp(str(text))

    encoding = tokenizer(str(text), return_tensors="pt", return_offsets_mapping=True, truncation=True)
    input_ids = encoding["input_ids"]
    offset_mappings = encoding["offset_mapping"][0]

    with torch.no_grad():
        output = model(input_ids)
    
    logits = output.logits
    predictions = torch.argmax(logits, dim=2)[0].tolist()

    for idx_token, pred_id in enumerate(predictions):
        start, end = offset_mappings[idx_token].tolist()
        if start == end:
            continue

        word_text = text[start:end]
        pos_tag = id2label[pred_id]
        lemma = None
        for token in spacy_doc:
            token_start = token.idx
            token_end = token.idx + len(token.text)
            if start >= token_start and end <= token_end:
                lemma = token.lemma_
                break
        if lemma is None:
            lemma = word_text.lower()

        results.append({
            "post_id": idx,
            "date": row.get("date"),
            "word": word_text,
            "lemma": lemma,
            "pos": pos_tag,
            "lemma_p": f"{lemma}_{pos_tag}"
        })

ber = pd.DataFrame(results)
ber.to_csv("testkorpus_divers_50_bert.csv", index=False)
display(ber.head(40))
# Out:
# Some weights of the model checkpoint at vblagoje/bert-english-uncased-finetuned-pos were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#     post_id        date         word                      lemma    pos  \
# 0         0  2010-11-04     Reminder                   reminder   NOUN
# 1         0  2010-11-04            :                          :  PUNCT
# 2         0  2010-11-04          The                        the    DET
# 3         0  2010-11-04         Miss                       Miss  PROPN
# 4         0  2010-11-04     Universe                   Universe  PROPN
# 5         0  2010-11-04  competition                competition   NOUN
# 6         0  2010-11-04         will                       will    AUX
# 7         0  2010-11-04           be                         be    AUX
# 8         0  2010-11-04         LIVE                       live    ADJ
# 9         0  2010-11-04         from                       from    ADP
# 10        0  2010-11-04          the                        the    DET
# 11        0  2010-11-04      Bahamas                    Bahamas  PROPN
# 12        0  2010-11-04            -                          -  PUNCT
# 13        0  2010-11-04      Tonight                    tonight   NOUN
# 14        0  2010-11-04            @                          @    ADP
# 15        0  2010-11-04            9                          9    NUM
# 16        0  2010-11-04           pm                         pm   NOUN
# 17        0  2010-11-04            (                          (  PUNCT
# 18        0  2010-11-04          EST                        EST   NOUN
# 19        0  2010-11-04            )                          )  PUNCT
# 20        0  2010-11-04           on                         on    ADP
# 21        0  2010-11-04          NBC                        NBC  PROPN
# 22        0  2010-11-04            :                          :  PUNCT
# 23        0  2010-11-04         http  http://tinyurl.com/mrzad9      X
# 24        0  2010-11-04            :  http://tinyurl.com/mrzad9  PUNCT
# 25        0  2010-11-04            /  http://tinyurl.com/mrzad9  PUNCT
# 26        0  2010-11-04            /  http://tinyurl.com/mrzad9  PUNCT
# 27        0  2010-11-04         tiny  http://tinyurl.com/mrzad9      X
# 28        0  2010-11-04           ur  http://tinyurl.com/mrzad9      X
# 29        0  2010-11-04            l  http://tinyurl.com/mrzad9      X
# 30        0  2010-11-04            .  http://tinyurl.com/mrzad9   NOUN
# 31        0  2010-11-04          com  http://tinyurl.com/mrzad9  PROPN
# 32        0  2010-11-04            /  http://tinyurl.com/mrzad9  PUNCT
# 33        0  2010-11-04           mr  http://tinyurl.com/mrzad9      X
# 34        0  2010-11-04           za  http://tinyurl.com/mrzad9      X
# 35        0  2010-11-04            d  http://tinyurl.com/mrzad9      X
# 36        0  2010-11-04            9  http://tinyurl.com/mrzad9   NOUN
# 37        1  2013-08-15            @                  @timc1021    SYM
# 38        1  2013-08-15          Tim                  @timc1021   NOUN
# 39        1  2013-08-15            c                  @timc1021   NOUN
#
#                             lemma_p
# 0                     reminder_NOUN
# 1                           :_PUNCT
# 2                           the_DET
# 3                        Miss_PROPN
# 4                    Universe_PROPN
# 5                  competition_NOUN
# 6                          will_AUX
# 7                            be_AUX
# 8                          live_ADJ
# 9                          from_ADP
# 10                          the_DET
# 11                    Bahamas_PROPN
# 12                          -_PUNCT
# 13                     tonight_NOUN
# 14                            @_ADP
# 15                            9_NUM
# 16                          pm_NOUN
# 17                          (_PUNCT
# 18                         EST_NOUN
# 19                          )_PUNCT
# 20                           on_ADP
# 21                        NBC_PROPN
# 22                          :_PUNCT
# 23      http://tinyurl.com/mrzad9_X
# 24  http://tinyurl.com/mrzad9_PUNCT
# 25  http://tinyurl.com/mrzad9_PUNCT
# 26  http://tinyurl.com/mrzad9_PUNCT
# 27      http://tinyurl.com/mrzad9_X
# 28      http://tinyurl.com/mrzad9_X
# 29      http://tinyurl.com/mrzad9_X
# 30   http://tinyurl.com/mrzad9_NOUN
# 31  http://tinyurl.com/mrzad9_PROPN
# 32  http://tinyurl.com/mrzad9_PUNCT
# 33      http://tinyurl.com/mrzad9_X
# 34      http://tinyurl.com/mrzad9_X
# 35      http://tinyurl.com/mrzad9_X
# 36   http://tinyurl.com/mrzad9_NOUN
# 37                    @timc1021_SYM
# 38                   @timc1021_NOUN
# 39                   @timc1021_NOUN

# %%
import pandas as pd
ber = pd.read_csv("testkorpus_divers_50_bert.csv")
display(ber[115:165])
# Out:
#      post_id        date             word           lemma    pos  \
# 115        4  2020-05-11                ’              ’s   PART
# 116        4  2020-05-11                s              ’s   PART
# 117        4  2020-05-11         Comments         comment   NOUN
# 118        4  2020-05-11               On              on    ADP
# 119        4  2020-05-11                “               "  PUNCT
# 120        4  2020-05-11             Meet            Meet   VERB
# 121        4  2020-05-11              The             The    DET
# 122        4  2020-05-11            Press           Press  PROPN
# 123        4  2020-05-11                ,               ,  PUNCT
# 124        4  2020-05-11                ”               "  PUNCT
# 125        4  2020-05-11             Todd            todd  PROPN
# 126        4  2020-05-11                …               …  PUNCT
# 127        5  2011-09-07               RT              RT  PROPN
# 128        5  2011-09-07                @       @magaglam    SYM
# 129        5  2011-09-07      MagaGlam🇺🇸♥     magaglam🇺🇸♥    SYM
# 130        5  2011-09-07            Bring           bring   VERB
# 131        5  2011-09-07             Back            back    ADV
# 132        5  2011-09-07            Trump           Trump  PROPN
# 133        5  2011-09-07              💙🇺🇸             💙🇺🇸    SYM
# 134        7  2025-03-19              The             the    DET
# 135        7  2025-03-19               CB             CBP  PROPN
# 136        7  2025-03-19                P             CBP  PROPN
# 137        7  2025-03-19             Home            Home   NOUN
# 138        7  2025-03-19              App             App   NOUN
# 139        7  2025-03-19               is              be    AUX
# 140        7  2025-03-19              now             now    ADV
# 141        7  2025-03-19        available       available    ADJ
# 142        7  2025-03-19           across          across    ADP
# 143        7  2025-03-19              all             all    DET
# 144        7  2025-03-19           mobile          mobile    ADJ
# 145        7  2025-03-19              App             App   NOUN
# 146        7  2025-03-19           Stores           store   NOUN
# 147        7  2025-03-19                !               !  PUNCT
# 148        8  2019-01-23  Congratulations  congratulation   NOUN
# 149        8  2019-01-23               to              to    ADP
# 150        8  2019-01-23          Mariano         Mariano  PROPN
# 151        8  2019-01-23           Rivera          Rivera  PROPN
# 152        8  2019-01-23               on              on  SCONJ
# 153        8  2019-01-23      unanimously     unanimously    ADV
# 154        8  2019-01-23            being              be    AUX
# 155        8  2019-01-23          elected           elect   VERB
# 156        8  2019-01-23               to              to    ADP
# 157        8  2019-01-23              the             the    DET
# 158        8  2019-01-23         National        National  PROPN
# 159        8  2019-01-23         Baseball        Baseball  PROPN
# 160        8  2019-01-23             Hall            Hall  PROPN
# 161        8  2019-01-23               of              of    ADP
# 162        8  2019-01-23             Fame            Fame  PROPN
# 163        8  2019-01-23                !               !  PUNCT
# 164        8  2019-01-23              Not             not    ADV
#
#                  lemma_p
# 115              ’s_PART
# 116              ’s_PART
# 117         comment_NOUN
# 118               on_ADP
# 119              "_PUNCT
# 120            Meet_VERB
# 121              The_DET
# 122          Press_PROPN
# 123              ,_PUNCT
# 124              "_PUNCT
# 125           todd_PROPN
# 126              …_PUNCT
# 127             RT_PROPN
# 128        @magaglam_SYM
# 129      magaglam🇺🇸♥_SYM
# 130           bring_VERB
# 131             back_ADV
# 132          Trump_PROPN
# 133              💙🇺🇸_SYM
# 134              the_DET
# 135            CBP_PROPN
# 136            CBP_PROPN
# 137            Home_NOUN
# 138             App_NOUN
# 139               be_AUX
# 140              now_ADV
# 141        available_ADJ
# 142           across_ADP
# 143              all_DET
# 144           mobile_ADJ
# 145             App_NOUN
# 146           store_NOUN
# 147              !_PUNCT
# 148  congratulation_NOUN
# 149               to_ADP
# 150        Mariano_PROPN
# 151         Rivera_PROPN
# 152             on_SCONJ
# 153      unanimously_ADV
# 154               be_AUX
# 155           elect_VERB
# 156               to_ADP
# 157              the_DET
# 158       National_PROPN
# 159       Baseball_PROPN
# 160           Hall_PROPN
# 161               of_ADP
# 162           Fame_PROPN
# 163              !_PUNCT
# 164              not_ADV

# %%
#### Bert2 ####
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline
import spacy

df = pd.read_csv("testkorpus_divers_50.csv")
nlp = spacy.load("en_core_web_sm")

model_name = "vblagoje/bert-english-uncased-finetuned-pos"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)

pos_tagger = pipeline("token-classification", model=model, tokenizer=tokenizer, aggregation_strategy="simple")

results = []

for idx, row in df.iterrows():
    text = row["text"]
    if pd.isna(text):
        continue

    spacy_doc = nlp(str(text))
    hf_pos = pos_tagger(str(text))
    spacy_tokens = list(spacy_doc)
    
    def get_spacy_token_by_offset(start, end):
        for token in spacy_tokens:
            token_start = token.idx
            token_end = token.idx + len(token.text)
            if token_start <= end and token_end >= start:
                return token
        return None
    
    for entity in hf_pos:
        word = entity['word']
        start = entity['start']
        end = entity['end']
        pos_tag = entity['entity_group']  # z.B. 'NOUN', 'VERB'
        
        spacy_token = get_spacy_token_by_offset(start, end)
        lemma = spacy_token.lemma_ if spacy_token else word.lower()
        
        results.append({
            "post_id": idx,
            "date": row.get("date"),
            "word": word,
            "lemma": lemma,
            "pos": pos_tag,
            "lemma_p": f"{lemma}_{pos_tag}"
        })

bert = pd.DataFrame(results)
bert.to_csv("testkorpus_divers_50_bert2.csv", index=False)
display(bert.head(50))
# Out:
# Some weights of the model checkpoint at vblagoje/bert-english-uncased-finetuned-pos were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
#     post_id        date           word                      lemma    pos  \
# 0         0  2010-11-04       reminder                   reminder   NOUN
# 1         0  2010-11-04              :                   reminder  PUNCT
# 2         0  2010-11-04            the                        the    DET
# 3         0  2010-11-04  miss universe                       Miss  PROPN
# 4         0  2010-11-04    competition                competition   NOUN
# 5         0  2010-11-04        will be                       will    AUX
# 6         0  2010-11-04           live                       live    ADJ
# 7         0  2010-11-04           from                       from    ADP
# 8         0  2010-11-04            the                        the    DET
# 9         0  2010-11-04        bahamas                    Bahamas  PROPN
# 10        0  2010-11-04              -                          -  PUNCT
# 11        0  2010-11-04        tonight                    tonight   NOUN
# 12        0  2010-11-04              @                          @    ADP
# 13        0  2010-11-04              9                          9    NUM
# 14        0  2010-11-04           ##pm                          9   NOUN
# 15        0  2010-11-04              (                          (  PUNCT
# 16        0  2010-11-04            est                          (   NOUN
# 17        0  2010-11-04              )                        EST  PUNCT
# 18        0  2010-11-04             on                         on    ADP
# 19        0  2010-11-04            nbc                        NBC  PROPN
# 20        0  2010-11-04              :                        NBC  PUNCT
# 21        0  2010-11-04           http  http://tinyurl.com/mrzad9      X
# 22        0  2010-11-04          : / /  http://tinyurl.com/mrzad9  PUNCT
# 23        0  2010-11-04        tinyurl  http://tinyurl.com/mrzad9      X
# 24        0  2010-11-04              .  http://tinyurl.com/mrzad9   NOUN
# 25        0  2010-11-04            com  http://tinyurl.com/mrzad9  PROPN
# 26        0  2010-11-04              /  http://tinyurl.com/mrzad9  PUNCT
# 27        0  2010-11-04          mrzad  http://tinyurl.com/mrzad9      X
# 28        0  2010-11-04            ##9  http://tinyurl.com/mrzad9   NOUN
# 29        1  2013-08-15              @                  @timc1021    SYM
# 30        1  2013-08-15           timc                  @timc1021   NOUN
# 31        1  2013-08-15         ##1021                  @timc1021    NUM
# 32        1  2013-08-15         thanks                      thank   NOUN
# 33        1  2013-08-15              !                      thank  PUNCT
# 34        2  2013-06-12            " "                          "  PUNCT
# 35        2  2013-06-12            @ _                          "    SYM
# 36        2  2013-06-12  katherinewebb            @_KatherineWebb  PROPN
# 37        2  2013-06-12              :            @_KatherineWebb  PUNCT
# 38        2  2013-06-12        looking                       look   VERB
# 39        2  2013-06-12        forward                    forward    ADV
# 40        2  2013-06-12             to                         to    ADP
# 41        2  2013-06-12              #                          #    SYM
# 42        2  2013-06-12        missusa                          #  PROPN
# 43        2  2013-06-12           this                       this    DET
# 44        2  2013-06-12        weekend                    weekend   NOUN
# 45        2  2013-06-12             in                         in    ADP
# 46        2  2013-06-12          vegas                      Vegas  PROPN
# 47        2  2013-06-12          ! " "                      Vegas  PUNCT
# 48        2  2013-06-12          great                               ADJ
# 49        2  2013-06-12             to                         to   PART
#
#                             lemma_p
# 0                     reminder_NOUN
# 1                    reminder_PUNCT
# 2                           the_DET
# 3                        Miss_PROPN
# 4                  competition_NOUN
# 5                          will_AUX
# 6                          live_ADJ
# 7                          from_ADP
# 8                           the_DET
# 9                     Bahamas_PROPN
# 10                          -_PUNCT
# 11                     tonight_NOUN
# 12                            @_ADP
# 13                            9_NUM
# 14                           9_NOUN
# 15                          (_PUNCT
# 16                           (_NOUN
# 17                        EST_PUNCT
# 18                           on_ADP
# 19                        NBC_PROPN
# 20                        NBC_PUNCT
# 21      http://tinyurl.com/mrzad9_X
# 22  http://tinyurl.com/mrzad9_PUNCT
# 23      http://tinyurl.com/mrzad9_X
# 24   http://tinyurl.com/mrzad9_NOUN
# 25  http://tinyurl.com/mrzad9_PROPN
# 26  http://tinyurl.com/mrzad9_PUNCT
# 27      http://tinyurl.com/mrzad9_X
# 28   http://tinyurl.com/mrzad9_NOUN
# 29                    @timc1021_SYM
# 30                   @timc1021_NOUN
# 31                    @timc1021_NUM
# 32                       thank_NOUN
# 33                      thank_PUNCT
# 34                          "_PUNCT
# 35                            "_SYM
# 36            @_KatherineWebb_PROPN
# 37            @_KatherineWebb_PUNCT
# 38                        look_VERB
# 39                      forward_ADV
# 40                           to_ADP
# 41                            #_SYM
# 42                          #_PROPN
# 43                         this_DET
# 44                     weekend_NOUN
# 45                           in_ADP
# 46                      Vegas_PROPN
# 47                      Vegas_PUNCT
# 48                             _ADJ
# 49                          to_PART

# %%
import pandas as pd
fptfb = pd.read_csv("testkorpus_divers_50_bert2.csv")
display(bert[200:215])
# Out:
#      post_id        date           word        lemma    pos            lemma_p
# 200       10  2017-07-21         hosted         host   VERB          host_VERB
# 201       10  2017-07-21              a            a    DET              a_DET
# 202       10  2017-07-21              #            #    SYM              #_SYM
# 203       10  2017-07-21  madeinamerica            #      X                #_X
# 204       10  2017-07-21          event        event   NOUN         event_NOUN
# 205       10  2017-07-21              ,        event  PUNCT        event_PUNCT
# 206       10  2017-07-21     right here        right    ADV          right_ADV
# 207       10  2017-07-21             at           at    ADP             at_ADP
# 208       10  2017-07-21            the          the    DET            the_DET
# 209       10  2017-07-21              @  @whitehouse      X      @whitehouse_X
# 210       10  2017-07-21     whitehouse  @whitehouse  PROPN  @whitehouse_PROPN
# 211       10  2017-07-21              !  @whitehouse  PUNCT  @whitehouse_PUNCT
# 212       10  2017-07-21             if           if  SCONJ           if_SCONJ
# 213       10  2017-07-21             it           it   PRON            it_PRON
# 214       10  2017-07-21             is           be    AUX             be_AUX

# %%
bert.shape
# Out:
# (1559, 6)

# %%
bert[70:110]
# das Lemma ist völlig falsch
# @darhar wird als Satzzeichen erkannt?!
# Out:
#      post_id        date                   word       lemma    pos  \
# 70         4  2020-05-11                      :  @darhar981  PUNCT
# 71         4  2020-05-11  attorney general barr    Attorney  PROPN
# 72         4  2020-05-11                    ’ s        Barr   PART
# 73         4  2020-05-11                 office      office   NOUN
# 74         4  2020-05-11                 shreds       shred   VERB
# 75         4  2020-05-11                    nbc         NBC  PROPN
# 76         4  2020-05-11                    ’ s         NBC   PART
# 77         4  2020-05-11             chuck todd       Chuck  PROPN
# 78         4  2020-05-11                    for         for    ADP
# 79         4  2020-05-11                      ‘           '  PUNCT
# 80         4  2020-05-11              deceptive           '    ADJ
# 81         4  2020-05-11                editing     editing   NOUN
# 82         4  2020-05-11                      ’     editing  PUNCT
# 83         4  2020-05-11                     of          of    ADP
# 84         4  2020-05-11                   barr        Barr  PROPN
# 85         4  2020-05-11                    ’ s        Barr   PART
# 86         4  2020-05-11               comments     comment   NOUN
# 87         4  2020-05-11                     on          \n    ADP
# 88         4  2020-05-11                      “           "  PUNCT
# 89         4  2020-05-11                   meet           "   VERB
# 90         4  2020-05-11                    the         The    DET
# 91         4  2020-05-11                  press       Press  PROPN
# 92         4  2020-05-11                    , ”       Press  PUNCT
# 93         4  2020-05-11                   todd        todd  PROPN
# 94         4  2020-05-11                      …        todd  PUNCT
# 95         5  2011-09-07                     rt          RT  PROPN
# 96         5  2011-09-07          @ MagaGlam🇺🇸♥                SYM
# 97         5  2011-09-07                  bring       bring   VERB
# 98         5  2011-09-07                   back        back    ADV
# 99         5  2011-09-07                  trump              PROPN
# 100        5  2011-09-07                    💙🇺🇸                SYM
# 101        7  2025-03-19                    the         the    DET
# 102        7  2025-03-19                    cbp         CBP  PROPN
# 103        7  2025-03-19               home app        Home   NOUN
# 104        7  2025-03-19                     is          be    AUX
# 105        7  2025-03-19                    now         now    ADV
# 106        7  2025-03-19              available   available    ADJ
# 107        7  2025-03-19                 across      across    ADP
# 108        7  2025-03-19                    all         all    DET
# 109        7  2025-03-19                 mobile      mobile    ADJ
#
#               lemma_p
# 70   @darhar981_PUNCT
# 71     Attorney_PROPN
# 72          Barr_PART
# 73        office_NOUN
# 74         shred_VERB
# 75          NBC_PROPN
# 76           NBC_PART
# 77        Chuck_PROPN
# 78            for_ADP
# 79            '_PUNCT
# 80              '_ADJ
# 81       editing_NOUN
# 82      editing_PUNCT
# 83             of_ADP
# 84         Barr_PROPN
# 85          Barr_PART
# 86       comment_NOUN
# 87             \n_ADP
# 88            "_PUNCT
# 89             "_VERB
# 90            The_DET
# 91        Press_PROPN
# 92        Press_PUNCT
# 93         todd_PROPN
# 94         todd_PUNCT
# 95           RT_PROPN
# 96               _SYM
# 97         bring_VERB
# 98           back_ADV
# 99             _PROPN
# 100              _SYM
# 101           the_DET
# 102         CBP_PROPN
# 103         Home_NOUN
# 104            be_AUX
# 105           now_ADV
# 106     available_ADJ
# 107        across_ADP
# 108           all_DET
# 109        mobile_ADJ

# %%
#### Bert3 ### ohne Pipeline
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForTokenClassification
import spacy

model_name = "vblagoje/bert-english-uncased-finetuned-pos"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)
model.eval()
nlp = spacy.load("en_core_web_sm")
id2label = model.config.id2label

df = pd.read_csv("testkorpus_divers_50.csv")

results = []

for idx, row in df.iterrows():
    text = row["text"]
    if pd.isna(text):
        continue
    spacy_doc = nlp(str(text))
    
    encoding = tokenizer(str(text), return_tensors="pt", return_offsets_mapping=True, truncation=True)
    input_ids = encoding["input_ids"]
    offset_mappings = encoding["offset_mapping"][0]
    
    with torch.no_grad():
        output = model(input_ids)
    
    logits = output.logits  
    predictions = torch.argmax(logits, dim=2)[0].tolist()
    
    for idx_token, pred_id in enumerate(predictions):
        start, end = offset_mappings[idx_token].tolist()
        if start == end:
            continue
        
        word_text = text[start:end]
        pos_tag = id2label[pred_id]
        
        lemma = None
        for token in spacy_doc:
            token_start = token.idx
            token_end = token.idx + len(token.text)
            if start >= token_start and end <= token_end:
                lemma = token.lemma_
                break
        if lemma is None:
            lemma = word_text.lower()
        
        results.append({
            "post_id": idx,
            "date": row.get("date"),
            "word": word_text,
            "lemma": lemma,
            "pos": pos_tag,
            "lemma_p": f"{lemma}_{pos_tag}"
        })

bert3 = pd.DataFrame(results)
bert3.to_csv("testkorpus_divers_50_bert3.csv", index=False)
display(bert3.head(40))
# Out:
# Some weights of the model checkpoint at vblagoje/bert-english-uncased-finetuned-pos were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#     post_id        date         word                      lemma    pos  \
# 0         0  2010-11-04     Reminder                   reminder   NOUN
# 1         0  2010-11-04            :                          :  PUNCT
# 2         0  2010-11-04          The                        the    DET
# 3         0  2010-11-04         Miss                       Miss  PROPN
# 4         0  2010-11-04     Universe                   Universe  PROPN
# 5         0  2010-11-04  competition                competition   NOUN
# 6         0  2010-11-04         will                       will    AUX
# 7         0  2010-11-04           be                         be    AUX
# 8         0  2010-11-04         LIVE                       live    ADJ
# 9         0  2010-11-04         from                       from    ADP
# 10        0  2010-11-04          the                        the    DET
# 11        0  2010-11-04      Bahamas                    Bahamas  PROPN
# 12        0  2010-11-04            -                          -  PUNCT
# 13        0  2010-11-04      Tonight                    tonight   NOUN
# 14        0  2010-11-04            @                          @    ADP
# 15        0  2010-11-04            9                          9    NUM
# 16        0  2010-11-04           pm                         pm   NOUN
# 17        0  2010-11-04            (                          (  PUNCT
# 18        0  2010-11-04          EST                        EST   NOUN
# 19        0  2010-11-04            )                          )  PUNCT
# 20        0  2010-11-04           on                         on    ADP
# 21        0  2010-11-04          NBC                        NBC  PROPN
# 22        0  2010-11-04            :                          :  PUNCT
# 23        0  2010-11-04         http  http://tinyurl.com/mrzad9      X
# 24        0  2010-11-04            :  http://tinyurl.com/mrzad9  PUNCT
# 25        0  2010-11-04            /  http://tinyurl.com/mrzad9  PUNCT
# 26        0  2010-11-04            /  http://tinyurl.com/mrzad9  PUNCT
# 27        0  2010-11-04         tiny  http://tinyurl.com/mrzad9      X
# 28        0  2010-11-04           ur  http://tinyurl.com/mrzad9      X
# 29        0  2010-11-04            l  http://tinyurl.com/mrzad9      X
# 30        0  2010-11-04            .  http://tinyurl.com/mrzad9   NOUN
# 31        0  2010-11-04          com  http://tinyurl.com/mrzad9  PROPN
# 32        0  2010-11-04            /  http://tinyurl.com/mrzad9  PUNCT
# 33        0  2010-11-04           mr  http://tinyurl.com/mrzad9      X
# 34        0  2010-11-04           za  http://tinyurl.com/mrzad9      X
# 35        0  2010-11-04            d  http://tinyurl.com/mrzad9      X
# 36        0  2010-11-04            9  http://tinyurl.com/mrzad9   NOUN
# 37        1  2013-08-15            @                  @timc1021    SYM
# 38        1  2013-08-15          Tim                  @timc1021   NOUN
# 39        1  2013-08-15            c                  @timc1021   NOUN
#
#                             lemma_p
# 0                     reminder_NOUN
# 1                           :_PUNCT
# 2                           the_DET
# 3                        Miss_PROPN
# 4                    Universe_PROPN
# 5                  competition_NOUN
# 6                          will_AUX
# 7                            be_AUX
# 8                          live_ADJ
# 9                          from_ADP
# 10                          the_DET
# 11                    Bahamas_PROPN
# 12                          -_PUNCT
# 13                     tonight_NOUN
# 14                            @_ADP
# 15                            9_NUM
# 16                          pm_NOUN
# 17                          (_PUNCT
# 18                         EST_NOUN
# 19                          )_PUNCT
# 20                           on_ADP
# 21                        NBC_PROPN
# 22                          :_PUNCT
# 23      http://tinyurl.com/mrzad9_X
# 24  http://tinyurl.com/mrzad9_PUNCT
# 25  http://tinyurl.com/mrzad9_PUNCT
# 26  http://tinyurl.com/mrzad9_PUNCT
# 27      http://tinyurl.com/mrzad9_X
# 28      http://tinyurl.com/mrzad9_X
# 29      http://tinyurl.com/mrzad9_X
# 30   http://tinyurl.com/mrzad9_NOUN
# 31  http://tinyurl.com/mrzad9_PROPN
# 32  http://tinyurl.com/mrzad9_PUNCT
# 33      http://tinyurl.com/mrzad9_X
# 34      http://tinyurl.com/mrzad9_X
# 35      http://tinyurl.com/mrzad9_X
# 36   http://tinyurl.com/mrzad9_NOUN
# 37                    @timc1021_SYM
# 38                   @timc1021_NOUN
# 39                   @timc1021_NOUN

# %%
import pandas as pd
bert3 = pd.read_csv("testkorpus_divers_50_bert3.csv")
display(bert3[115:165])
# Out:
#      post_id        date             word           lemma    pos  \
# 115        4  2020-05-11                ’              ’s   PART
# 116        4  2020-05-11                s              ’s   PART
# 117        4  2020-05-11         Comments         comment   NOUN
# 118        4  2020-05-11               On              on    ADP
# 119        4  2020-05-11                “               "  PUNCT
# 120        4  2020-05-11             Meet            Meet   VERB
# 121        4  2020-05-11              The             The    DET
# 122        4  2020-05-11            Press           Press  PROPN
# 123        4  2020-05-11                ,               ,  PUNCT
# 124        4  2020-05-11                ”               "  PUNCT
# 125        4  2020-05-11             Todd            todd  PROPN
# 126        4  2020-05-11                …               …  PUNCT
# 127        5  2011-09-07               RT              RT  PROPN
# 128        5  2011-09-07                @       @magaglam    SYM
# 129        5  2011-09-07      MagaGlam🇺🇸♥     magaglam🇺🇸♥    SYM
# 130        5  2011-09-07            Bring           bring   VERB
# 131        5  2011-09-07             Back            back    ADV
# 132        5  2011-09-07            Trump           Trump  PROPN
# 133        5  2011-09-07              💙🇺🇸             💙🇺🇸    SYM
# 134        7  2025-03-19              The             the    DET
# 135        7  2025-03-19               CB             CBP  PROPN
# 136        7  2025-03-19                P             CBP  PROPN
# 137        7  2025-03-19             Home            Home   NOUN
# 138        7  2025-03-19              App             App   NOUN
# 139        7  2025-03-19               is              be    AUX
# 140        7  2025-03-19              now             now    ADV
# 141        7  2025-03-19        available       available    ADJ
# 142        7  2025-03-19           across          across    ADP
# 143        7  2025-03-19              all             all    DET
# 144        7  2025-03-19           mobile          mobile    ADJ
# 145        7  2025-03-19              App             App   NOUN
# 146        7  2025-03-19           Stores           store   NOUN
# 147        7  2025-03-19                !               !  PUNCT
# 148        8  2019-01-23  Congratulations  congratulation   NOUN
# 149        8  2019-01-23               to              to    ADP
# 150        8  2019-01-23          Mariano         Mariano  PROPN
# 151        8  2019-01-23           Rivera          Rivera  PROPN
# 152        8  2019-01-23               on              on  SCONJ
# 153        8  2019-01-23      unanimously     unanimously    ADV
# 154        8  2019-01-23            being              be    AUX
# 155        8  2019-01-23          elected           elect   VERB
# 156        8  2019-01-23               to              to    ADP
# 157        8  2019-01-23              the             the    DET
# 158        8  2019-01-23         National        National  PROPN
# 159        8  2019-01-23         Baseball        Baseball  PROPN
# 160        8  2019-01-23             Hall            Hall  PROPN
# 161        8  2019-01-23               of              of    ADP
# 162        8  2019-01-23             Fame            Fame  PROPN
# 163        8  2019-01-23                !               !  PUNCT
# 164        8  2019-01-23              Not             not    ADV
#
#                  lemma_p
# 115              ’s_PART
# 116              ’s_PART
# 117         comment_NOUN
# 118               on_ADP
# 119              "_PUNCT
# 120            Meet_VERB
# 121              The_DET
# 122          Press_PROPN
# 123              ,_PUNCT
# 124              "_PUNCT
# 125           todd_PROPN
# 126              …_PUNCT
# 127             RT_PROPN
# 128        @magaglam_SYM
# 129      magaglam🇺🇸♥_SYM
# 130           bring_VERB
# 131             back_ADV
# 132          Trump_PROPN
# 133              💙🇺🇸_SYM
# 134              the_DET
# 135            CBP_PROPN
# 136            CBP_PROPN
# 137            Home_NOUN
# 138             App_NOUN
# 139               be_AUX
# 140              now_ADV
# 141        available_ADJ
# 142           across_ADP
# 143              all_DET
# 144           mobile_ADJ
# 145             App_NOUN
# 146           store_NOUN
# 147              !_PUNCT
# 148  congratulation_NOUN
# 149               to_ADP
# 150        Mariano_PROPN
# 151         Rivera_PROPN
# 152             on_SCONJ
# 153      unanimously_ADV
# 154               be_AUX
# 155           elect_VERB
# 156               to_ADP
# 157              the_DET
# 158       National_PROPN
# 159       Baseball_PROPN
# 160           Hall_PROPN
# 161               of_ADP
# 162           Fame_PROPN
# 163              !_PUNCT
# 164              not_ADV

# %%
bert3.shape
# Out:
# (2024, 6)

# %%
bert3[1980:2024]
# Links und @ werden seltsam zerlegt
# Out:
#       post_id        date            word           lemma    pos  \
# 1980       49  2025-03-01            were              be    AUX
# 1981       49  2025-03-01        released         release   VERB
# 1982       49  2025-03-01            into            into    ADP
# 1983       49  2025-03-01             our             our   PRON
# 1984       49  2025-03-01         Country         Country   NOUN
# 1985       49  2025-03-01               .               .  PUNCT
# 1986       49  2025-03-01          Thanks           thank   NOUN
# 1987       49  2025-03-01              to              to    ADP
# 1988       49  2025-03-01             the             the    DET
# 1989       49  2025-03-01           Trump           Trump  PROPN
# 1990       49  2025-03-01  Administration  Administration   NOUN
# 1991       49  2025-03-01        Policies        Policies   NOUN
# 1992       49  2025-03-01               ,               ,  PUNCT
# 1993       49  2025-03-01             the             the    DET
# 1994       49  2025-03-01          Border          Border   NOUN
# 1995       49  2025-03-01              is              be    AUX
# 1996       49  2025-03-01          CLOSED          closed   VERB
# 1997       49  2025-03-01              to              to    ADP
# 1998       49  2025-03-01             all             all    DET
# 1999       49  2025-03-01         Illegal         Illegal    ADJ
# 2000       49  2025-03-01      Immigrants      Immigrants   NOUN
# 2001       49  2025-03-01               .               .  PUNCT
# 2002       49  2025-03-01          Anyone          anyone   PRON
# 2003       49  2025-03-01             who             who   PRON
# 2004       49  2025-03-01           tries             try   VERB
# 2005       49  2025-03-01              to              to   PART
# 2006       49  2025-03-01       illegally       illegally    ADV
# 2007       49  2025-03-01           enter           enter   VERB
# 2008       49  2025-03-01             the             the    DET
# 2009       49  2025-03-01               U          U.S.A.  PROPN
# 2010       49  2025-03-01               .          U.S.A.  PUNCT
# 2011       49  2025-03-01               S          U.S.A.  PROPN
# 2012       49  2025-03-01               .          U.S.A.  PUNCT
# 2013       49  2025-03-01               A          U.S.A.  PROPN
# 2014       49  2025-03-01               .          U.S.A.  PUNCT
# 2015       49  2025-03-01            will            will    AUX
# 2016       49  2025-03-01            face            face   VERB
# 2017       49  2025-03-01     significant     significant    ADJ
# 2018       49  2025-03-01        criminal        criminal    ADJ
# 2019       49  2025-03-01       penalties         penalty   NOUN
# 2020       49  2025-03-01             and             and  CCONJ
# 2021       49  2025-03-01       immediate       immediate    ADJ
# 2022       49  2025-03-01     deportation     deportation   NOUN
# 2023       49  2025-03-01               .               .  PUNCT
#
#                   lemma_p
# 1980               be_AUX
# 1981         release_VERB
# 1982             into_ADP
# 1983             our_PRON
# 1984         Country_NOUN
# 1985              ._PUNCT
# 1986           thank_NOUN
# 1987               to_ADP
# 1988              the_DET
# 1989          Trump_PROPN
# 1990  Administration_NOUN
# 1991        Policies_NOUN
# 1992              ,_PUNCT
# 1993              the_DET
# 1994          Border_NOUN
# 1995               be_AUX
# 1996          closed_VERB
# 1997               to_ADP
# 1998              all_DET
# 1999          Illegal_ADJ
# 2000      Immigrants_NOUN
# 2001              ._PUNCT
# 2002          anyone_PRON
# 2003             who_PRON
# 2004             try_VERB
# 2005              to_PART
# 2006        illegally_ADV
# 2007           enter_VERB
# 2008              the_DET
# 2009         U.S.A._PROPN
# 2010         U.S.A._PUNCT
# 2011         U.S.A._PROPN
# 2012         U.S.A._PUNCT
# 2013         U.S.A._PROPN
# 2014         U.S.A._PUNCT
# 2015             will_AUX
# 2016            face_VERB
# 2017      significant_ADJ
# 2018         criminal_ADJ
# 2019         penalty_NOUN
# 2020            and_CCONJ
# 2021        immediate_ADJ
# 2022     deportation_NOUN
# 2023              ._PUNCT

# %% [markdown]
# Fazit zu Bert:
# - die Links (und auch andere Abkürzungen wie CBP) werden in viel zu viele Einzelteile zerlegt und falsch bestimmt (Zahlen und sonstige Wörter auch: USA(Emoji) wird zu usa(emoji) und SYM, also falsch getrennt)
# - Hashes und @ werden getrennt (#MadeInAmerica wird zu # Made InA meric a)
# - Emojis werden als SYM erkannt (und wenn falsch getrennt auch der Rest des Wortes)
# - rchtige Lemmatisierung
# - ca. 7-8.000 Tags mehr als die anderen Tagger (wegen der Links wahrscheinlich)
# - bert3: Lemmatisierung schlecht und Trennung der Wörter schlecht (Opioid wird zu Op io id)
# - bert2: Uhrzeit mit ## ergänzt?, Lemmatisierung noch schlechter

# %% [markdown]
# ## Tweebank

# %%
# Die ältere Version TweebankNLP unterstützt kein POS-Tagging.
import tweetnlp
print(list(tweetnlp.loader.TASK_CLASS.keys()))
# Out:
# ['sentiment', 'offensive', 'irony', 'hate', 'emotion', 'emoji', 'stance_abortion', 'stance_atheism', 'stance_climate', 'stance_feminist', 'stance_hillary', 'topic_classification', 'ner', 'language_model', 'sentence_embedding', 'question_answering', 'question_answer_generation']

# %%
import torch
print(torch.__version__)
# Out:
# 2.6.0

# %%
#### Tweebank ####
import pandas as pd
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline
df = pd.read_csv("testkorpus_divers_50.csv")

df["text"] = df["text"].fillna("").astype(str)
model_name = "TweebankNLP/bertweet-tb2_ewt-pos-tagging"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)

# Device: CPU
device = -1

tagger = pipeline(
    "token-classification",
    model=model,
    tokenizer=tokenizer,
    aggregation_strategy="simple",
    device=device
)

results = []

for idx, row in df.iterrows():
    text = row["text"].strip()
    
    if text:
        tagged = tagger(text)
        for token_info in tagged:
            word_text = token_info.get("word")
            pos_tag = token_info.get("entity_group")
            lemma = word_text
            results.append({
                "post_id": idx,
                "date": row.get("date"),
                "word": word_text,
                "lemma": lemma,
                "pos": pos_tag,
                "lemma_p": f"{lemma}_{pos_tag}"
            })
    else:
        results.append({
            "post_id": idx,
            "date": row.get("date"),
            "word": "",
            "lemma": "",
            "pos": "",
            "lemma_p": ""
        })

twe = pd.DataFrame(results)
twe.to_csv("testkorpus_divers_50_tweebank_1.csv", index=False, encoding="utf-8")
display(twe.head())
# Out:
# Device set to use cpu
#    post_id        date           word          lemma    pos  \
# 0        0  2010-11-04     Reminder@@     Reminder@@   NOUN
# 1        0  2010-11-04              :              :  PUNCT
# 2        0  2010-11-04            The            The    DET
# 3        0  2010-11-04  Miss Universe  Miss Universe  PROPN
# 4        0  2010-11-04    competition    competition   NOUN
#
#                lemma_p
# 0      Reminder@@_NOUN
# 1              :_PUNCT
# 2              The_DET
# 3  Miss Universe_PROPN
# 4     competition_NOUN

# %%
import pandas as pd
twe = pd.read_csv("testkorpus_divers_50_tweebank_1.csv")
display(twe[70:115])
# Out:
#      post_id        date                     word                    lemma  \
# 70         4  2020-05-11                       Of                       Of
# 71         4  2020-05-11                   Barr@@                   Barr@@
# 72         4  2020-05-11                  <unk> s                  <unk> s
# 73         4  2020-05-11                 Comments                 Comments
# 74         4  2020-05-11                       On                       On
# 75         4  2020-05-11                    <unk>                    <unk>
# 76         4  2020-05-11                     Meet                     Meet
# 77         4  2020-05-11                      The                      The
# 78         4  2020-05-11                  Press@@                  Press@@
# 79         4  2020-05-11                       ,”                       ,”
# 80         4  2020-05-11                   Todd@@                   Todd@@
# 81         4  2020-05-11                        …                        …
# 82         5  2011-09-07           RT @MagaGlam@@           RT @MagaGlam@@
# 83         5  2011-09-07  <unk> <unk> <unk> <unk>  <unk> <unk> <unk> <unk>
# 84         5  2011-09-07                    Bring                    Bring
# 85         5  2011-09-07                     Back                     Back
# 86         5  2011-09-07                    Trump                    Trump
# 87         5  2011-09-07        <unk> <unk> <unk>        <unk> <unk> <unk>
# 88         6  2011-09-01                      NaN                      NaN
# 89         7  2025-03-19                      The                      The
# 90         7  2025-03-19                 CBP Home                 CBP Home
# 91         7  2025-03-19                      App                      App
# 92         7  2025-03-19                       is                       is
# 93         7  2025-03-19                      now                      now
# 94         7  2025-03-19                available                available
# 95         7  2025-03-19                   across                   across
# 96         7  2025-03-19                      all                      all
# 97         7  2025-03-19                   mobile                   mobile
# 98         7  2025-03-19             App Stores@@             App Stores@@
# 99         7  2025-03-19                        !                        !
# 100        8  2019-01-23          Congratulations          Congratulations
# 101        8  2019-01-23                       to                       to
# 102        8  2019-01-23           Mariano Rivera           Mariano Rivera
# 103        8  2019-01-23                       on                       on
# 104        8  2019-01-23              unanimously              unanimously
# 105        8  2019-01-23                    being                    being
# 106        8  2019-01-23                  elected                  elected
# 107        8  2019-01-23                       to                       to
# 108        8  2019-01-23                      the                      the
# 109        8  2019-01-23                 National                 National
# 110        8  2019-01-23            Baseball Hall            Baseball Hall
# 111        8  2019-01-23                       of                       of
# 112        8  2019-01-23                    Fam@@                    Fam@@
# 113        8  2019-01-23                      e@@                      e@@
# 114        8  2019-01-23                        !                        !
#
#        pos                      lemma_p
# 70     ADP                       Of_ADP
# 71   PROPN                 Barr@@_PROPN
# 72    PART                 <unk> s_PART
# 73    NOUN                Comments_NOUN
# 74     ADP                       On_ADP
# 75   PUNCT                  <unk>_PUNCT
# 76    VERB                    Meet_VERB
# 77     DET                      The_DET
# 78    NOUN                 Press@@_NOUN
# 79   PUNCT                     ,”_PUNCT
# 80   PROPN                 Todd@@_PROPN
# 81   PUNCT                      …_PUNCT
# 82       X             RT @MagaGlam@@_X
# 83     SYM  <unk> <unk> <unk> <unk>_SYM
# 84    VERB                   Bring_VERB
# 85     ADP                     Back_ADP
# 86   PROPN                  Trump_PROPN
# 87     SYM        <unk> <unk> <unk>_SYM
# 88     NaN                          NaN
# 89     DET                      The_DET
# 90   PROPN               CBP Home_PROPN
# 91    NOUN                     App_NOUN
# 92     AUX                       is_AUX
# 93     ADV                      now_ADV
# 94     ADJ                available_ADJ
# 95     ADP                   across_ADP
# 96     DET                      all_DET
# 97     ADJ                   mobile_ADJ
# 98    NOUN            App Stores@@_NOUN
# 99   PUNCT                      !_PUNCT
# 100   NOUN         Congratulations_NOUN
# 101    ADP                       to_ADP
# 102  PROPN         Mariano Rivera_PROPN
# 103  SCONJ                     on_SCONJ
# 104    ADV              unanimously_ADV
# 105    AUX                    being_AUX
# 106   VERB                 elected_VERB
# 107    ADP                       to_ADP
# 108    DET                      the_DET
# 109    ADJ                 National_ADJ
# 110  PROPN          Baseball Hall_PROPN
# 111    ADP                       of_ADP
# 112  PROPN                  Fam@@_PROPN
# 113   NOUN                     e@@_NOUN
# 114  PUNCT                      !_PUNCT

# %%
twe.shape
# Emojis durch @ ersetzt??
# Out:
# (1225, 6)

# %%
#### Tweebank mit SpaCy ####
import pandas as pd
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline
import spacy

df = pd.read_csv("testkorpus_divers_50.csv")
model_name = "TweebankNLP/bertweet-tb2_ewt-pos-tagging"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)
tagger = pipeline("token-classification", model=model, tokenizer=tokenizer, aggregation_strategy="simple")

nlp = spacy.load("en_core_web_sm")

results = []

for idx, row in df.iterrows():
    text = str(row["text"])
    date = row.get("date", None)

    # POS-Tagging mit Tweebank
    pos_tags = tagger(text)

    # Lemmatisierung mit spaCy
    doc = nlp(text)

    lemma_map = {token.text: token.lemma_ for token in doc}

    for token_info in pos_tags:
        word_text = token_info["word"]
        pos_tag = token_info["entity_group"]
        lemma = lemma_map.get(word_text, word_text)

        results.append({
            "post_id": idx,
            "date": date,
            "word": word_text,
            "lemma": lemma,
            "pos": pos_tag,
            "lemma_p": f"{lemma}_{pos_tag}"
        })

twesp = pd.DataFrame(results)
twesp.to_csv("testkorpus_divers_50_tweebank.csv", index=False)
display(twesp.head())
# Out:
# Device set to use cpu
#    post_id        date           word          lemma    pos  \
# 0        0  2010-11-04     Reminder@@     Reminder@@   NOUN
# 1        0  2010-11-04              :              :  PUNCT
# 2        0  2010-11-04            The            the    DET
# 3        0  2010-11-04  Miss Universe  Miss Universe  PROPN
# 4        0  2010-11-04    competition    competition   NOUN
#
#                lemma_p
# 0      Reminder@@_NOUN
# 1              :_PUNCT
# 2              the_DET
# 3  Miss Universe_PROPN
# 4     competition_NOUN

# %% [markdown]
# Device set to use cpu:
# Auf MacOs gibt es normalerweise keine CUDA-GPU.
# Apple Silicon (M1/M2/M3) hat eine eigene GPU, die nur über PyTorch mit MPS (Metal Performance Shaders) genutzt werden kann.
# Auf Intel-Macs bleibt nur die CPU.

# %%
import pandas as pd
twesp = pd.read_csv("testkorpus_divers_50_tweebank.csv")
display(twesp[70:115])
# Out:
#      post_id        date                     word                    lemma  \
# 70         4  2020-05-11                       Of                       of
# 71         4  2020-05-11                   Barr@@                   Barr@@
# 72         4  2020-05-11                  <unk> s                  <unk> s
# 73         4  2020-05-11                 Comments                  comment
# 74         4  2020-05-11                       On                       on
# 75         4  2020-05-11                    <unk>                    <unk>
# 76         4  2020-05-11                     Meet                     Meet
# 77         4  2020-05-11                      The                      The
# 78         4  2020-05-11                  Press@@                  Press@@
# 79         4  2020-05-11                       ,”                       ,”
# 80         4  2020-05-11                   Todd@@                   Todd@@
# 81         4  2020-05-11                        …                        …
# 82         5  2011-09-07           RT @MagaGlam@@           RT @MagaGlam@@
# 83         5  2011-09-07  <unk> <unk> <unk> <unk>  <unk> <unk> <unk> <unk>
# 84         5  2011-09-07                    Bring                    bring
# 85         5  2011-09-07                     Back                     back
# 86         5  2011-09-07                    Trump                    Trump
# 87         5  2011-09-07        <unk> <unk> <unk>        <unk> <unk> <unk>
# 88         6  2011-09-01                      NaN                      NaN
# 89         7  2025-03-19                      The                      the
# 90         7  2025-03-19                 CBP Home                 CBP Home
# 91         7  2025-03-19                      App                      App
# 92         7  2025-03-19                       is                       be
# 93         7  2025-03-19                      now                      now
# 94         7  2025-03-19                available                available
# 95         7  2025-03-19                   across                   across
# 96         7  2025-03-19                      all                      all
# 97         7  2025-03-19                   mobile                   mobile
# 98         7  2025-03-19             App Stores@@             App Stores@@
# 99         7  2025-03-19                        !                        !
# 100        8  2019-01-23          Congratulations           congratulation
# 101        8  2019-01-23                       to                       to
# 102        8  2019-01-23           Mariano Rivera           Mariano Rivera
# 103        8  2019-01-23                       on                       on
# 104        8  2019-01-23              unanimously              unanimously
# 105        8  2019-01-23                    being                       be
# 106        8  2019-01-23                  elected                    elect
# 107        8  2019-01-23                       to                       to
# 108        8  2019-01-23                      the                      the
# 109        8  2019-01-23                 National                 National
# 110        8  2019-01-23            Baseball Hall            Baseball Hall
# 111        8  2019-01-23                       of                       of
# 112        8  2019-01-23                    Fam@@                    Fam@@
# 113        8  2019-01-23                      e@@                      e@@
# 114        8  2019-01-23                        !                        !
#
#        pos                      lemma_p
# 70     ADP                       of_ADP
# 71   PROPN                 Barr@@_PROPN
# 72    PART                 <unk> s_PART
# 73    NOUN                 comment_NOUN
# 74     ADP                       on_ADP
# 75   PUNCT                  <unk>_PUNCT
# 76    VERB                    Meet_VERB
# 77     DET                      The_DET
# 78    NOUN                 Press@@_NOUN
# 79   PUNCT                     ,”_PUNCT
# 80   PROPN                 Todd@@_PROPN
# 81   PUNCT                      …_PUNCT
# 82       X             RT @MagaGlam@@_X
# 83     SYM  <unk> <unk> <unk> <unk>_SYM
# 84    VERB                   bring_VERB
# 85     ADP                     back_ADP
# 86   PROPN                  Trump_PROPN
# 87     SYM        <unk> <unk> <unk>_SYM
# 88   PROPN                    nan_PROPN
# 89     DET                      the_DET
# 90   PROPN               CBP Home_PROPN
# 91    NOUN                     App_NOUN
# 92     AUX                       be_AUX
# 93     ADV                      now_ADV
# 94     ADJ                available_ADJ
# 95     ADP                   across_ADP
# 96     DET                      all_DET
# 97     ADJ                   mobile_ADJ
# 98    NOUN            App Stores@@_NOUN
# 99   PUNCT                      !_PUNCT
# 100   NOUN          congratulation_NOUN
# 101    ADP                       to_ADP
# 102  PROPN         Mariano Rivera_PROPN
# 103  SCONJ                     on_SCONJ
# 104    ADV              unanimously_ADV
# 105    AUX                       be_AUX
# 106   VERB                   elect_VERB
# 107    ADP                       to_ADP
# 108    DET                      the_DET
# 109    ADJ                 National_ADJ
# 110  PROPN          Baseball Hall_PROPN
# 111    ADP                       of_ADP
# 112  PROPN                  Fam@@_PROPN
# 113   NOUN                     e@@_NOUN
# 114  PUNCT                      !_PUNCT

# %%
twesp.shape
# Out:
# (1225, 6)

# %%
#### Tweebank mit Stanza ####
import pandas as pd
import stanza
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

df = pd.read_csv("testkorpus_divers_50.csv")

model_name = "TweebankNLP/bertweet-tb2_ewt-pos-tagging"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)
tagger = pipeline(
    "token-classification",
    model=model,
    tokenizer=tokenizer,
    aggregation_strategy="simple"
)

stanza.download("en")
nlp_stanza = stanza.Pipeline(
    lang="en",
    processors="tokenize,lemma",
    tokenize_engine="tokenize/tweet"  # Tweet-Tokenizer
)

results = []

for idx, row in df.iterrows():
    text = str(row["text"])
    date = row.get("date", None)

    if not isinstance(text, str) or text.strip() == "":
        continue

    # Tokenisierung und Lemmatisierung mit Stanza
    doc = nlp_stanza(text)
    tokens = [(w.text, w.lemma) for s in doc.sentences for w in s.words]

    words = [t[0] for t in tokens]
    pos_tags_nested = tagger(words)
    pos_tags = [tag[0] if isinstance(tag, list) else tag for tag in pos_tags_nested]

    for token_info, (word_text, lemma) in zip(pos_tags, tokens):
        pos_tag = token_info["entity_group"]

        results.append({
            "post_id": idx,
            "date": date,
            "word": word_text,
            "lemma": lemma,
            "pos": pos_tag,
            "lemma_p": f"{lemma}_{pos_tag}",
        })

twesta = pd.DataFrame(results)
twesta.to_csv("testkorpus_divers_50_tweebank2.csv", index=False, encoding="utf-8")
display(twesta.head())
# Out:
# Device set to use cpu
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-09-13 15:01:34 INFO: Downloaded file to /Users/vivien/stanza_resources/resources.json
# 2025-09-13 15:01:34 INFO: Downloading default packages for language: en (English) ...
# 2025-09-13 15:01:37 INFO: File exists: /Users/vivien/stanza_resources/en/default.zip
# 2025-09-13 15:01:43 INFO: Finished downloading models and saved to /Users/vivien/stanza_resources
# 2025-09-13 15:01:43 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-09-13 15:06:43 INFO: Downloaded file to /Users/vivien/stanza_resources/resources.json
# 2025-09-13 15:06:44 WARNING: Language en package default expects mwt, which has been added
# 2025-09-13 15:06:44 INFO: Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# 2025-09-13 15:06:44 INFO: Using device: cpu
# 2025-09-13 15:06:44 INFO: Loading: tokenize
# 2025-09-13 15:06:44 INFO: Loading: mwt
# 2025-09-13 15:06:44 INFO: Loading: lemma
# 2025-09-13 15:06:45 INFO: Done loading processors!
#    post_id        date      word     lemma    pos        lemma_p
# 0        0  2010-11-04  Reminder  reminder   NOUN  reminder_NOUN
# 1        0  2010-11-04         :         :  PUNCT        :_PUNCT
# 2        0  2010-11-04       The       the    DET        the_DET
# 3        0  2010-11-04      Miss      Miss  PROPN     Miss_PROPN
# 4        0  2010-11-04  Universe  Universe   NOUN  Universe_NOUN

# %%
import pandas as pd
twesta = pd.read_csv("testkorpus_divers_50_tweebank2.csv")
display(twesta[70:115])
# Out:
#      post_id        date             word           lemma    pos  \
# 70         4  2020-05-11           Shreds          shreds   NOUN
# 71         4  2020-05-11              NBC             NBC  PROPN
# 72         4  2020-05-11               ’s              's   PRON
# 73         4  2020-05-11            Chuck           Chuck  PROPN
# 74         4  2020-05-11             Todd            Todd  PROPN
# 75         4  2020-05-11              For             for   INTJ
# 76         4  2020-05-11                ‘               '  PUNCT
# 77         4  2020-05-11        Deceptive       deceptive    ADJ
# 78         4  2020-05-11          Editing         editing   NOUN
# 79         4  2020-05-11                ’              's  PUNCT
# 80         4  2020-05-11               Of              of    ADV
# 81         4  2020-05-11             Barr            barr  PROPN
# 82         4  2020-05-11               ’s              's   PRON
# 83         4  2020-05-11         Comments         comment   NOUN
# 84         4  2020-05-11               On              on    ADJ
# 85         4  2020-05-11                “              ''  PUNCT
# 86         4  2020-05-11             Meet            meet   VERB
# 87         4  2020-05-11              The             the    DET
# 88         4  2020-05-11            Press           Press   NOUN
# 89         4  2020-05-11                ,               ,  PUNCT
# 90         4  2020-05-11                ”              ''  PUNCT
# 91         4  2020-05-11             Todd            Todd  PROPN
# 92         4  2020-05-11                …               …    SYM
# 93         5  2011-09-07               RT              rt   VERB
# 94         5  2011-09-07                @               @    SYM
# 95         5  2011-09-07     MagaGlam🇺🇸♥️    magaglam🇺🇸♥️  PROPN
# 96         5  2011-09-07            Bring           bring   VERB
# 97         5  2011-09-07             Back            back    ADV
# 98         5  2011-09-07            Trump           Trump  PROPN
# 99         5  2011-09-07              💙🇺🇸             💙🇺🇸    SYM
# 100        6  2011-09-01              NaN             NaN  PROPN
# 101        7  2025-03-19              The             the    DET
# 102        7  2025-03-19              CBP             cbp  PROPN
# 103        7  2025-03-19             Home            Home   NOUN
# 104        7  2025-03-19              App             app   NOUN
# 105        7  2025-03-19               is              be   VERB
# 106        7  2025-03-19              now             now    ADV
# 107        7  2025-03-19        available       available    ADJ
# 108        7  2025-03-19           across          across    ADV
# 109        7  2025-03-19              all             all    DET
# 110        7  2025-03-19           mobile          mobile    ADJ
# 111        7  2025-03-19              App             app   NOUN
# 112        7  2025-03-19           Stores          stores   NOUN
# 113        7  2025-03-19                !               !  PUNCT
# 114        8  2019-01-23  Congratulations  congratulation   NOUN
#
#                  lemma_p
# 70           shreds_NOUN
# 71             NBC_PROPN
# 72               's_PRON
# 73           Chuck_PROPN
# 74            Todd_PROPN
# 75              for_INTJ
# 76               '_PUNCT
# 77         deceptive_ADJ
# 78          editing_NOUN
# 79              's_PUNCT
# 80                of_ADV
# 81            barr_PROPN
# 82               's_PRON
# 83          comment_NOUN
# 84                on_ADJ
# 85              ''_PUNCT
# 86             meet_VERB
# 87               the_DET
# 88            Press_NOUN
# 89               ,_PUNCT
# 90              ''_PUNCT
# 91            Todd_PROPN
# 92                 …_SYM
# 93               rt_VERB
# 94                 @_SYM
# 95    magaglam🇺🇸♥️_PROPN
# 96            bring_VERB
# 97              back_ADV
# 98           Trump_PROPN
# 99               💙🇺🇸_SYM
# 100            nan_PROPN
# 101              the_DET
# 102            cbp_PROPN
# 103            Home_NOUN
# 104             app_NOUN
# 105              be_VERB
# 106              now_ADV
# 107        available_ADJ
# 108           across_ADV
# 109              all_DET
# 110           mobile_ADJ
# 111             app_NOUN
# 112          stores_NOUN
# 113              !_PUNCT
# 114  congratulation_NOUN

# %%
twesta.shape
# Out:
# (1209, 6)

# %% [markdown]
# Fazit zu Tweebank:
# - Emojis werden in <unk/> umgewandelt plus @@ ?!
# - MWEs werden erkannt
# - Emojis in @@,
# - Worte falsch getrennt (v.a. bei Satzzeichen)
# - bei Trennung immer @@ ergänzt
# - einen Zeichenfehler gut erkannt
# - Hashtag bleibt zusammen, aber mit X gelabelt
# - Emojis als unkown und SYM gelabelt
# - Links bleiben ganz und als X
# - kein Unterschied zwischen den zwei Codes (0,1)
# - Lemma immer wie Word bei 1 & 2
# - bei Tagging und Lemmatisierung mit Stanza besseres Ergebnis

# %% [markdown]
# # Finale Entscheidung und Tagging der Daten

# %% [markdown]
# Ich entscheide mich für... STANZA mit Tweet-Tokenizer

# %% [raw]
# import pandas as pd
# import stanza
# import re
#
# stanza.download("en")
#
# # Stanza-Pipeline mit Tweet-Tokenizer
# nlp = stanza.Pipeline(
#     lang="en",
#     processors="tokenize,pos,lemma",
#     tokenize_pretokenized=False,
#     use_gpu=False,
#     tokenize_with_spacy=False,
#     tokenize_no_ssplit=False,
#     tokenize_engine="tokenize/tweet"   # spezieller Tweet-Tokenizer
# )
#
#
# # Unicode-Emoji-Regex
# emoji_pattern = re.compile("["
#     u"\U0001F600-\U0001F64F"  # Emoticons
#     u"\U0001F300-\U0001F5FF"  # Symbole & Piktogramme
#     u"\U0001F680-\U0001F6FF"  # Transport & Symbole
#     u"\U0001F1E0-\U0001F1FF"  # Flaggen
#     "]+", flags=re.UNICODE)
#
# # klassische Smileys
# smiley_pattern = re.compile(r'[:;=8][\-~]?[)D]', flags=re.UNICODE)
#
# def is_emoji_or_smiley(token):
#     return bool(emoji_pattern.fullmatch(token)) or bool(smiley_pattern.fullmatch(token))
#
#
# df = pd.read_csv("testkorpus_divers_50.csv")
# all_results = []
#
# for idx, row in df.iterrows():
#     text = row.get("text")
#     if pd.isna(text) or not isinstance(text, str) or text.strip() == "":
#         continue
#
#     doc = nlp(text)
#     for sentence in doc.sentences:
#         for word in sentence.words:
#             xpos = word.xpos
#             if is_emoji_or_smiley(word.text):
#                 xpos = "NFP"
#
#             lemma_p = f"{word.lemma}_{word.upos}"
#             all_results.append({
#                 "post_id": idx + 1,
#                 "date": row.get("date"),
#                 "word": word.text,
#                 "lemma": word.lemma,
#                 "pos": word.upos,
#                 "xpos": xpos,
#                 "lemma_p": lemma_p,
#             })
#
# pos_df = pd.DataFrame(all_results)
# output_file = "testkorpus_divers_50_stanza_tweets2.csv"
# pos_df.to_csv(output_file, index=False, encoding="utf-8")
# display(pos_df.head(20))

# %% [markdown]
# Hier die beiden Varianten des Tagging mit extra Tags für Tweets:

# %% [markdown]
# ### Mapping Tabelle:
# | `xpos` (Tweebank / PTB) | `upos` (Universal) | Bedeutung / Beispiele                                                                  |
# | ----------------------- | ------------------ | -------------------------------------------------------------------------------------- |
# | **NN**                  | NOUN               | Noun, singular → *dog, idea*                                                           |
# | **NNS**                 | NOUN               | Noun, plural → *dogs, cars*                                                            |
# | **NNP**                 | PROPN              | Proper noun, singular → *Trump, Canada*                                                |
# | **NNPS**                | PROPN              | Proper noun, plural → *the Smiths*                                                     |
# | **PRP**                 | PRON               | Personal pronoun → *I, you, he*                                                        |
# | **PRP\$**               | PRON               | Possessive pronoun → *my, your*                                                        |
# | **WP**                  | PRON               | Wh-pronoun → *who, what*                                                               |
# | **WP\$**                | PRON               | Possessive wh-pronoun → *whose*                                                        |
# | **DT**                  | DET                | Determiner → *the, a, some*                                                            |
# | **PDT**                 | DET                | Predeterminer → *all the kids*                                                         |
# | **WDT**                 | DET                | Wh-determiner → *which*                                                                |
# | **JJ**                  | ADJ                | Adjective → *big, nice*                                                                |
# | **JJR**                 | ADJ                | Comparative adj → *bigger*                                                             |
# | **JJS**                 | ADJ                | Superlative adj → *biggest*                                                            |
# | **RB**                  | ADV                | Adverb → *quickly*                                                                     |
# | **RBR**                 | ADV                | Comparative adv → *faster*                                                             |
# | **RBS**                 | ADV                | Superlative adv → *fastest*                                                            |
# | **WRB**                 | ADV                | Wh-adverb → *how, when, why*                                                           |
# | **VB**                  | VERB               | Verb base → *eat, go*                                                                  |
# | **VBD**                 | VERB               | Verb past → *ate, went*                                                                |
# | **VBG**                 | VERB               | Verb gerund/participle → *eating*                                                      |
# | **VBN**                 | VERB               | Verb past participle → *eaten*                                                         |
# | **VBP**                 | VERB               | Verb non-3sg present → *eat, go*                                                       |
# | **VBZ**                 | VERB               | Verb 3sg present → *eats, goes*                                                        |
# | **MD**                  | AUX                | Modal → *can, should*                                                                  |
# | **IN**                  | ADP                | Preposition, subordinating → *in, of, because*                                         |
# | **TO**                  | PART               | Particle *to*                                                                          |
# | **CC**                  | CCONJ              | Coordinating conj → *and, or*                                                          |
# | **UH**                  | INTJ               | Interjection → *oh, hi*                                                                |
# | **EX**                  | PRON               | Existential *there*                                                                    |
# | **FW**                  | X                  | Foreign word                                                                           |
# | **SYM**                 | SYM                | Symbol → *%, \$, +*                                                                    |
# | **LS**                  | X                  | List item marker                                                                       |
# | **CD**                  | NUM                | Cardinal number → *5, twenty*                                                          |
# | **POS**                 | PART               | Possessive marker *’s*                                                                 |
# | **RP**                  | PART               | Particle → *up, off*                                                                   |
# | **ADD**                 | PROPN              | **Spezialtag Tweebank**: URL, Email, @mention, Hashtag → *@user, #hashtag, https\://…* |
# | **NFP**                 | SYM                | **Spezialtag Tweebank**: Non-functional punctuation → *🤣, :), ❤️*                     |
# | **. , : ; - etc.**      | PUNCT              | Satzzeichen                                                                            |
