# %% [markdown]
# # Kommunikationsstrategien

# %% [markdown]
# Die beiden verwendeten Tagsets:

# %% [markdown]
# | `xpos` (Tweebank / PTB) | `upos` (Universal Dependencies) | Bedeutung / Beispiele                                                                  |
# | ----------------------- | ------------------ | -------------------------------------------------------------------------------------- |
# | **NN**                  | NOUN               | Noun, singular → *dog, idea*                                                           |
# | **NNS**                 | NOUN               | Noun, plural → *dogs, cars*                                                            |
# | **NNP**                 | PROPN              | Proper noun, singular → *Trump, Canada*                                                |
# | **NNPS**                | PROPN              | Proper noun, plural → *the Smiths*                                                     |
# | **PRP**                 | PRON               | Personal pronoun → *I, you, he*                                                        |
# | **PRP\$**               | PRON               | Possessive pronoun → *my, your*                                                        |
# | **WP**                  | PRON               | Wh-pronoun → *who, what*                                                               |
# | **WP\$**                | PRON               | Possessive wh-pronoun → *whose*                                                        |
# | **DT**                  | DET                | Determiner → *the, a, some*                                                            |
# | **PDT**                 | DET                | Predeterminer → *all the kids*                                                         |
# | **WDT**                 | DET                | Wh-determiner → *which*                                                                |
# | **JJ**                  | ADJ                | Adjective → *big, nice*                                                                |
# | **JJR**                 | ADJ                | Comparative adj → *bigger*                                                             |
# | **JJS**                 | ADJ                | Superlative adj → *biggest*                                                            |
# | **RB**                  | ADV                | Adverb → *quickly*                                                                     |
# | **RBR**                 | ADV                | Comparative adv → *faster*                                                             |
# | **RBS**                 | ADV                | Superlative adv → *fastest*                                                            |
# | **WRB**                 | ADV                | Wh-adverb → *how, when, why*                                                           |
# | **VB**                  | VERB               | Verb base → *eat, go*                                                                  |
# | **VBD**                 | VERB               | Verb past → *ate, went*                                                                |
# | **VBG**                 | VERB               | Verb gerund/participle → *eating*                                                      |
# | **VBN**                 | VERB               | Verb past participle → *eaten*                                                         |
# | **VBP**                 | VERB               | Verb non-3sg present → *eat, go*                                                       |
# | **VBZ**                 | VERB               | Verb 3sg present → *eats, goes*                                                        |
# | **MD**                  | AUX                | Modal → *can, should*                                                                  |
# | **IN**                  | ADP                | Preposition, subordinating → *in, of, because*                                         |
# | **TO**                  | PART               | Particle *to*                                                                          |
# | **CC**                  | CCONJ              | Coordinating conj → *and, or*                                                          |
# | **UH**                  | INTJ               | Interjection → *oh, hi*                                                                |
# | **EX**                  | PRON               | Existential *there*                                                                    |
# | **FW**                  | X                  | Foreign word                                                                           |
# | **SYM**                 | SYM                | Symbol → *%, \$, +*                                                                    |
# | **LS**                  | X                  | List item marker                                                                       |
# | **CD**                  | NUM                | Cardinal number → *5, twenty*                                                          |
# | **POS**                 | PART               | Possessive marker *’s*                                                                 |
# | **RP**                  | PART               | Particle → *up, off*                                                                   |
# | **ADD**                 | PROPN              | **Spezialtag Tweebank**: URL, Email, @mention, Hashtag → *@user, #hashtag, https\://…* |
# | **NFP**                 | SYM                | **Spezialtag Tweebank**: Non-functional punctuation → *🤣, :), ❤️*                     |
# | **. , : ; - etc.**      | PUNCT              | Satzzeichen                                                                            |

# %% [markdown]
# #### 11. Autoritätsargument (Appeal to authority): Wahrheitsgehalt durch Autorität begründen
# - I, because, clever, Elon, Donald, engineer, scientist, expert

# %% [markdown]
# #### 12. Gedanken-lenkende Klischees (Thought-Terminating Cliché): Aussagen, die kritische oder sinnvolle Diskussionen verhinden
# - fake news, deep state, mainstream media, woke, cancel culture, alien

# %% [markdown]
# #### 13. Schwar-Weiß-Denken (Black-and-White Fallacy) und Dictatorship: Leuten sagen, was sie denken, fühlen, tun sollen
# - Republicians, Democrats, good, bad, right, wrong, legal, illegal

# %% [markdown]
# #### 14. Reductio ad Hitlerum: Aussagen einer Gegenposition gehassten Gruppen zuordnen
# - „First they wanted small censorship, next thing you know — X.“, „Who else did things like this? Think about X.“ „That’s exactly what X did.“ „X-like policy“,
# - policy, idea, action, support(ing), just like, just as, -esque, -style, .*like

# %% [markdown]
# #### 15. Wiederholung (Repetition):
# - Frequenzanalysen siehe Notebook 04 und 05

# %% [markdown]
# #### 16. Verschleierung, Verwirrung, Absichtliche Vagheit (Obfuscation, Intentional Vagueness, Confusion): absichtlich allgemeine Formulierungen nutzen, um viel Interpretationsspielraum zu lassen
# - thing, all, every(thing/one), each, people, situation, issue, problem, stuff, something, anything

# %% [markdown]
# #### 17. Red Herring (Presenting Irrelevant Data): Verwendung irrelevanter Argumente (zur Verwirrung und Spaltung):
# - meanwhile, different, besides, however, irrelevant

# %% [markdown]
# #### 18. Bandwagon: Zielgruppe zu Handlung überreden ("weil es alle anderen auch machen")
# - everyone, all, together, (you) should, join, support, movement, we must, let's

# %% [markdown]
# #### 19. Verleumdung (Smears): Ruhmschädigung durch negative Propaganda
# - siehe 2.
# - liar, corrupt, crooked, crazy, criminal, fraud, traitor, disgrace

# %% [markdown]
# #### 20. Glänzende Verallgemeinerungen (Glittering Generalities, Virtue): Verwendung von Symbolen eines Wertsystems zur Steigerung des Ansehens
# - freedom, security, safety, justice, truth, values, god, peace, loyalty

# %% [markdown]
# #### 21. Bilder zum Wecken starker Emotionen (Appeal to strong emotions)
# - safe, secure, danger, fight, war, money, health, wealth
# - siehe 6. "eat"

# %% [markdown]
# #### 22. Assoziation/ Transfer: Projektion emotionaler Reaktionen auf Personen/Themen/Werte
# - great, poor, legal, illeagal, hero, winner, beautiful, smart, brilliant

# %% [markdown]
# #### Musk spezifisch:
# - Gaming
# - Tech, machine, business
# - free speech
